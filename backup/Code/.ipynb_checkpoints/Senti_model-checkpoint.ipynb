# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import nltk
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ravishankarbhati/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("../Data/train_F3WbcTw.csv")

# %%
df.shape
# Out:
# (5279, 4)

# %%
df.columns
# Out:
# Index(['unique_hash', 'text', 'drug', 'sentiment'], dtype='object')

# %%
df.head()
# Out:
#                                 unique_hash  \
# 0  2e180be4c9214c1f5ab51fd8cc32bc80c9f612e0
# 1  9eba8f80e7e20f3a2f48685530748fbfa95943e4
# 2  fe809672251f6bd0d986e00380f48d047c7e7b76
# 3  bd22104dfa9ec80db4099523e03fae7a52735eb6
# 4  b227688381f9b25e5b65109dd00f7f895e838249
#
#                                                 text        drug  sentiment
# 0  Autoimmune diseases tend to come in clusters. ...     gilenya          2
# 1  I can completely understand why you’d want to ...     gilenya          2
# 2  Interesting that it only targets S1P-1/5 recep...  fingolimod          2
# 3  Very interesting, grand merci. Now I wonder wh...     ocrevus          2
# 4  Hi everybody, My latest MRI results for Brain ...     gilenya          1

# %%
df.drop(columns="unique_hash",axis=1,inplace=True)

# %%
df.shape
# Out:
# (5279, 3)

# %%
df.columns
# Out:
# Index(['text', 'drug', 'sentiment'], dtype='object')

# %% [markdown]
# ### makethe text to lowercase for all

# %%
df["text"] = df["text"].apply(lambda x:x.lower())

# %%
appos = {
"aren't" : "are not",
"can't" : "cannot",
"couldn't" : "could not",
"didn't" : "did not",
"doesn't" : "does not",
"don't" : "do not",
"hadn't" : "had not",
"hasn't" : "has not",
"haven't" : "have not",
"he'd" : "he would",
"he'll" : "he will",
"he's" : "he is",
"i'd" : "I would",
"i'd" : "I had",
"i'll" : "I will",
"i'm" : "I am",
"isn't" : "is not",
"it's" : "it is",
"it'll":"it will",
"i've" : "I have",
"let's" : "let us",
"mightn't" : "might not",
"mustn't" : "must not",
"shan't" : "shall not",
"she'd" : "she would",
"she'll" : "she will",
"she's" : "she is",
"shouldn't" : "should not",
"that's" : "that is",
"there's" : "there is",
"they'd" : "they would",
"they'll" : "they will",
"they're" : "they are",
"they've" : "they have",
"we'd" : "we would",
"we're" : "we are",
"weren't" : "were not",
"we've" : "we have",
"what'll" : "what will",
"what're" : "what are",
"what's" : "what is",
"what've" : "what have",
"where's" : "where is",
"who'd" : "who would",
"who'll" : "who will",
"who're" : "who are",
"who's" : "who is",
"who've" : "who have",
"won't" : "will not",
"wouldn't" : "would not",
"you'd" : "you would",
"you'll" : "you will",
"you're" : "you are",
"you've" : "you have",
"'re": " are",
"wasn't": "was not",
"we'll":" will",
"didn't": "did not"
}

# %%
df.head()
# Out:
#                                                 text        drug  sentiment
# 0  autoimmune diseases tend to come in clusters. ...     gilenya          2
# 1  i can completely understand why you’d want to ...     gilenya          2
# 2  interesting that it only targets s1p-1/5 recep...  fingolimod          2
# 3  very interesting, grand merci. now i wonder wh...     ocrevus          2
# 4  hi everybody, my latest mri results for brain ...     gilenya          1

# %% [markdown]
# ###  get the list of stop words and lemmatize the words

# %%
stopwords = set(stopwords.words("english"))

# %%
len(stopwords)
# Out:
# 179

# %%
#stopwords

# %%
word_lematizer = WordNetLemmatizer()

# %%
len(df[ df.sentiment == 0])
# Out:
# 617

# %%
len(df[ df.sentiment == 1])
# Out:
# 837

# %%
len(df[ df.sentiment == 2])
# Out:
# 3825

# %%
len(df.drug.unique())
# Out:
# 102

# %%
neutral_reviews = df[ df.sentiment == 2].sample(n=617)

# %%
neutral_reviews.head()
# Out:
#                                                    text     drug  sentiment
# 1625  summary: investigators are recruiting 600 peop...  gilenya          2
# 2395  those raspberry ketone tablets are a big con i...  gilenya          2
# 1755  well i’m currently taking gilenya. i’ve never ...  gilenya          2
# 2205  @danlancslad , so how’s it been going for you ...  gilenya          2
# 3330  @curious-one iv heard wonderful things about o...  ocrevus          2

# %%
len(neutral_reviews["drug"].value_counts())
# Out:
# 57

# %%
len(df["drug"].unique())
# Out:
# 102

# %%
len(df[df.sentiment == 0]["drug"].value_counts())
# Out:
# 57

# %%
len(df[df.sentiment == 1]["drug"].value_counts())
# Out:
# 54

# %%
len(df[df.sentiment == 2]["drug"].value_counts())
# Out:
# 97

# %%
df.columns
# Out:
# Index(['text', 'drug', 'sentiment'], dtype='object')

# %%
neutral_rev= pd.DataFrame(columns=['text', 'drug', 'sentiment'])

# %%
neutral_rev
# Out:
# Empty DataFrame
# Columns: [text, drug, sentiment]
# Index: []

# %%
for dg in df.drug.unique() :
    neu_review = df[ (df['sentiment']==2) & (df['drug']== dg)]
    if(len(neu_review))>20 :
        neu_sample = neu_review.sample(n=16)
    else :
        neu_sample = neu_review
    #print(neu_sample)
    neutral_rev = neutral_rev.append(neu_sample)
    #print(neutral_rev)

# %%
neutral_rev.shape
# Out:
# (861, 3)

# %%
( (neutral_rev.drug.value_counts() >=6)).value_counts()
# Out:
# True     52
# False    45
# Name: drug, dtype: int64

# %%
#df.drug.value_counts().sort_values(ascending=False)

# %%
drug_value_counts = df.drug.value_counts().tolist()

# %%
np.median(drug_value_counts)
# Out:
# 7.0

# %%
np.std(drug_value_counts)
# Out:
# 116.44483977946336

# %%
plt.plot(drug_value_counts)

# %%
np.percentile(drug_value_counts,75)
# Out:
# 33.0

# %%
drug_value_more = ( ( df.drug.value_counts() > int(np.percentile(drug_value_counts,75)) )==True ).keys().tolist()

# %%
neutral_rev.shape
# Out:
# (861, 3)

# %%
pos_rev = df[ df.sentiment==0 ]
pos_rev.shape
# Out:
# (617, 3)

# %%
neg_rev= df[ df.sentiment==1]
neg_rev.shape
# Out:
# (837, 3)

# %%
neutral_rev.head(2)
# Out:
#                                                    text     drug sentiment
# 2634  btw, aubagio is the weakest of the available o...  gilenya         2
# 284   "doctor and i, together, decided to begin copa...  gilenya         2

# %%
neu_rev= neutral_rev

# %%
pos_rev.head(2)
# Out:
#                                                  text         drug  sentiment
# 6   reply posted for jesszidek. hi jess sorry to r...       humira          0
# 28  last updated: january 01, 2017.  share | comme...  ocrelizumab          0

# %%
neg_rev.head(2)
# Out:
#                                                 text        drug  sentiment
# 4  hi everybody, my latest mri results for brain ...     gilenya          1
# 8  why do you think that fingolimod was such a mi...  fingolimod          1

# %% [markdown]
# ##  data pre processing done

# %% [markdown]
# ## taking the test data given an dformatting it to run the model on it

# %%
from string import punctuation
import re

# %%
def hasPunctuations(inputString):
    return any(char for char in inputString if(char not in punctuation))

# %%
def GetTokens(text):
    tokens = nltk.tokenize.word_tokenize(text)
    
    #tokens = [t for t in tokens if (hasPunctuations(t)==False) ]
    
    temp_tokens = tokens
    for token in temp_tokens :
        if (re.match(r'\w',token)):
            tokens.remove(token)
            token = re.sub(r'[0-9]',"",token)
            tokens.append(token)
        elif (re.match(r'\W',token)):
            tokens.remove(token)
            token = re.sub(r'\W',"",token)
            token = re.sub(r'[0-9]',"",token)
            if(len(token.strip())> 2 and len(token.strip()) < 20):
                if( ( token.find("www")== -1 and token.find("html")== -1 and token.find("http")== -1 and token.find("blog")==-1 and token.find("youtube")==-1 
                     and token.find("org")==-1) ):
                    tokens.append(token)
    
    for token in tokens:
        if(token.strip() in appos.keys()):
            token = appos[token.strip()]
            
    #tokens = [appos[t.strip()] for t in tokens if(t.strip() in appos.keys())]
    #print(tokens)
    tokens = [t for t in tokens if (len(t.strip())>2)]
    tokens = [t for t in tokens if (len(t.strip())<15)]
    tokens = [t for t in tokens if t not in stopwords]
    tokens = [ word_lematizer.lemmatize(t) for t in tokens]
    
    return tokens

# %%
current_index=0
pos_tokens = []
neg_tokens = []
neu_tokens = []
word_index_map = {}

pos_tokenized = []
neg_tokenized = []
neu_tokenized = []

for review in pos_rev.text :
    tokens = GetTokens(review)
    #print(tokens)
    pos_tokenized.append(tokens)
    for token in tokens:
        if(token not in word_index_map) :
            word_index_map[token]=current_index
            current_index += 1

for review in neg_rev.text :
    tokens = GetTokens(review)
    neg_tokenized.append(tokens)
    for token in tokens:
        if(token not in word_index_map) :
            word_index_map[token]=current_index
            current_index += 1

for review in neu_rev.text :
    tokens = GetTokens(review)
    neu_tokenized.append(tokens)
    for token in tokens:
        if(token not in word_index_map) :
            word_index_map[token]=current_index
            current_index += 1

# %%
len(word_index_map)
# Out:
# 29726

# %%
#datatest = np.zeros( ( len(pos_tokenized)+len(neg_tokenized)+len(neu_tokenized), len(word_index_map)) )

# %%
#len(word_index_map)

# %%
data = np.zeros( ( len(pos_tokenized)+len(neg_tokenized)+len(neu_tokenized), len(word_index_map)+1 ) )

# %%
data.shape
# Out:
# (2315, 29727)

# %%
def TokenToVectors(tokens,label) :
    x= np.zeros(len(word_index_map) +1)
    
    for token in tokens:
        index = word_index_map[token]
        x[index] +=1
    
    x = x/x.sum()
    x[-1]=label
    
    return x

i =0

for tokens in pos_tokenized :
    x_row = TokenToVectors(tokens,0)
    data[i,:]= x_row
    i += 1

for tokens in neg_tokenized :
    x_row = TokenToVectors(tokens,1)
    data[i,:]= x_row
    i += 1

for tokens in neu_tokenized :
    x_row = TokenToVectors(tokens,2)
    data[i,:]= x_row
    i += 1

# %%
data.shape
# Out:
# (2315, 29727)

# %%
from keras.preprocessing import sequence,text
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense,Dropout,Embedding,LSTM,Conv1D,GlobalMaxPooling1D,Flatten,MaxPooling1D,GRU,SpatialDropout1D,Bidirectional
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
# Out:
# /home/ravishankarbhati/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
maxlen = 125
max_features = 5000

#X, Y, test_X = format_data(train, test, max_features, maxlen)

# %%
from keras.utils import to_categorical

# %%
np.random.shuffle(data)

# %%
Y = to_categorical(data[:,-1])

# %%
X = data[: , :-1]

# %%
model = Sequential()


model.add(Embedding(max_features,100,mask_zero=True))
model.add(LSTM(64,dropout=0.4, recurrent_dropout=0.4,return_sequences=True))
model.add(LSTM(32,dropout=0.5, recurrent_dropout=0.5,return_sequences=False))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 100)         500000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          42240
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 554,755
# Trainable params: 554,755
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 3
batch_size = 25

# %%
np.random.shuffle(data)

total_len=int(len(data) * 0.8)

# %%
X_train = X[0:total_len , :]
Y_train = Y[0:total_len]

X_test = X[total_len : , :]
Y_test = Y[total_len:]

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train[:,0:5000], Y_train, validation_data=(X_test, Y_test), epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# Train on 1852 samples, validate on 463 samples
# Epoch 1/3

# %% [markdown]
# ### split the data and create models

# %%
np.random.shuffle(data)

total_len=int(len(data) * 0.8)

# %%
total_len
# Out:
# 1852

# %%
X = data[: , :-1]
Y = data[:,-1]

X_train = X[0:total_len , :]
Y_train = Y[0:total_len]

X_test = X[total_len : , :]
Y_test = Y[total_len:]

# %%
from sklearn.linear_model import LogisticRegression

# %%
logis_model = LogisticRegression()

# %%
logis_model.fit(X,Y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
logis_model.score(X,Y)
# Out:
# 0.5529157667386609

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest_model = RandomForestClassifier(n_estimators=10)

# %%
randomforest_model.fit(X,Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
randomforest_model.score(X,Y)
# Out:
# 0.9926565874730021

# %%
import lightgbm as lgb

# %%
lgb_train = lgb.Dataset(X,Y)
#lgb_eval = lgb.Dataset(, Y, reference=lgb_train)
params = {}
params['learning_rate'] = 0.03
params['boosting_type'] = 'gbdt'
params['objective'] = 'multiclass'
params['num_class'] = 3
params['metric'] = 'multi_logloss'
params['sub_feature'] = 0.6
params['num_leaves'] = 40
#params['min_data_in_leaf'] = 100
params['bagging_fraction'] = 0.6
params['bagging_freq'] = 3

#lgb_model = lgb.train(params,lgb_train,num_boost_round=1000)
lgb_cv = lgb.cv(params, lgb_train, num_boost_round=2000, nfold=5, stratified=True, verbose_eval=20, early_stopping_rounds=100)

nround = lgb_cv['multi_logloss-mean'].index(np.min(lgb_cv['multi_logloss-mean']))
#print(nround)

model = lgb.train(params, lgb_train, num_boost_round=1000)
# Out:
# [20]	cv_agg's multi_logloss: 0.990392 + 0.00369702
# [40]	cv_agg's multi_logloss: 0.934841 + 0.00872677
# [60]	cv_agg's multi_logloss: 0.901812 + 0.0129012
# [80]	cv_agg's multi_logloss: 0.882669 + 0.0148297
# [100]	cv_agg's multi_logloss: 0.869973 + 0.0164483
# [120]	cv_agg's multi_logloss: 0.864327 + 0.0153755
# [140]	cv_agg's multi_logloss: 0.858247 + 0.0152993
# [160]	cv_agg's multi_logloss: 0.857266 + 0.0176572
# [180]	cv_agg's multi_logloss: 0.858382 + 0.0187526
# [200]	cv_agg's multi_logloss: 0.861416 + 0.0208172
# [220]	cv_agg's multi_logloss: 0.864146 + 0.0224846
# [240]	cv_agg's multi_logloss: 0.869402 + 0.0245383

# %% [markdown]
# ## import the test data and run the model on it

# %%
testdata= pd.read_csv("../Data/test_tOlRoBf.csv")

# %%
testdata.head()
# Out:
#                                 unique_hash  \
# 0  9e9a8166b84114aca147bf409f6f956635034c08
# 1  e747e6822c867571afe7b907b51f0f2ca67b0e1a
# 2  50b6d851bcff4f35afe354937949e9948975adf7
# 3  7f82ec2176ae6ab0b5d20b5ffc767ac829f384ae
# 4  8b37d169dee5bdae27060949242fb54feb6a7f7f
#
#                                                 text        drug
# 0  256 (previously stable on natalizumab), with 5...  fingolimod
# 1  On fingolimod and have been since December 201...  fingolimod
# 2  Apparently it's shingles! :-/ I do have a few ...      humira
# 3  If the Docetaxel doing once a week x3 weeks th...    tagrisso
# 4  CC, Stelara worked in a matter of days for me....     stelara

# %%
testdata["text"] = testdata["text"].apply(lambda x:x.lower())

# %%
testdata.shape
# Out:
# (2924, 3)

# %%
from string import punctuation

# %%
#samplesubmission = pd.read_csv("../Data/sample_submission_i5xnIZD.csv")

# %%
#samplesubmission.head()

# %%
current_index=0
pos_tokens = []
neg_tokens = []
neu_tokens = []
word_index_map_test = {}

review_tokenized = []

for review in testdata.text :
    tokens = GetTokens(review)
    
    for token in tokens:
        if(token not in word_index_map) :
            tokens.remove(token)
    
    review_tokenized.append(tokens)

# %%
datatest = np.zeros( ( len(review_tokenized), len(word_index_map)) )

# %%
datatest.shape
# Out:
# (2924, 29726)

# %%
def TokenToVectorsTest(tokens) :
    x= np.zeros(len(word_index_map))
    
    for token in tokens:
        if(token in word_index_map):
            index = word_index_map[token]
            x[index] +=1
    
    x = x/x.sum()
    #x[-1]=label
    
    return x

# %%
review_tokenized[0]
# Out:
# ['stable', 'natalizumab', 'switching', 'fingolimod', 'previously']

# %%
i =0

for tokens in review_tokenized :
    #print(tokens)
    x_row = TokenToVectorsTest(tokens)
    datatest[i,:]= x_row
    i += 1

# %%
#ypreds = randomforest_model.predict(datatest)

# %%
ypreds1 = model.predict(datatest)

# %%
ypreds = []

for x in ypreds1:
    ypreds.append(np.argmax(x))

# %%
from sklearn.metrics import f1_score

# %%
len(ypreds)
# Out:
# 2924

# %%
testdata["sentiment"] = [ y for y in ypreds]

# %%
testdata.head()
# Out:
#                                 unique_hash  \
# 0  9e9a8166b84114aca147bf409f6f956635034c08
# 1  e747e6822c867571afe7b907b51f0f2ca67b0e1a
# 2  50b6d851bcff4f35afe354937949e9948975adf7
# 3  7f82ec2176ae6ab0b5d20b5ffc767ac829f384ae
# 4  8b37d169dee5bdae27060949242fb54feb6a7f7f
#
#                                                 text        drug  sentiment
# 0  256 (previously stable on natalizumab), with 5...  fingolimod          1
# 1  on fingolimod and have been since december 201...  fingolimod          0
# 2  apparently it's shingles! :-/ i do have a few ...      humira          2
# 3  if the docetaxel doing once a week x3 weeks th...    tagrisso          2
# 4  cc, stelara worked in a matter of days for me....     stelara          2

# %%
final_submission_file = testdata[["unique_hash","sentiment"]]

# %%
final_submission_file.shape
# Out:
# (2924, 2)

# %%
final_submission_file.to_csv("submission.csv",index=False)

# %% [markdown]
# # <red><b><h2> try removing urls, creating category for integers/numbers</h2></b></red>

# %%
import re

# %%
temp_data = pd.DataFrame(data[ : , :-1], columns=word_index_map)

# %%
print(temp_data.columns)
# Out:
# Index(['posted', 'jesszidek', 'sorry', 'read', 'mentioned', 'lot', 'know',
#        'said', 'scared', 'humira',
#        ...
#        'benelux', 'iib/iii', 'cosentyx', 'sacroiliac', 'belgium-based',
#        'luxembourg', 'mega-blockbuster', 'lakeside', 'walid', 'one-to-one'],
#       dtype='object', length=30590)

# %%
toks = word_index_map.keys()

w_tokens= []

count=0
for tok in toks:
    if (re.match(r'\w',tok)):
        #tok = re.sub(r'[0-9]',"",tok)
        #print(tok)
        w_tokens.append(tok)
        count +=1

print(count)

not_w_tokens= []

count=0
for tok in toks:
    if (re.match(r'\W',tok)):
        #tok = re.sub(r'[0-9]',"",tok)
        #print(tok)
        not_w_tokens.append(tok)
        count +=1

print(count)

temp_w_tokens = []

count=0
for tok in w_tokens:
    if (re.match(r'\w',tok)):
        actualtok = tok
        tok = re.sub(r'[0-9]',"",tok)
        #print(tok)
        
        if(len(tok.strip())> 2):
            temp_w_tokens.append(tok)
            
        count +=1

print(count)

#len(temp_w_tokens)

temp_not_w_tokens = []

count=0
for tok in not_w_tokens:
    tok = re.sub(r'\W',"",tok)
    tok = re.sub(r'[0-9]',"",tok)
    #print(tok)
    
    if(len(tok.strip())> 2 and len(tok.strip()) < 20):
        if( ( tok.find("www")== -1 and tok.find("html")== -1 and 
            tok.find("blog")==-1 and tok.find("youtube")==-1 
            and tok.find("org")==-1) ):
            temp_not_w_tokens.append(tok)
    count +=1

print(count)
# Out:
# 30181
# 409
# 30181
# 409

# %%
len(temp_not_w_tokens)
# Out:
# 199

# %%
#temp_not_w_tokens

# %%
text_pre_tokens=temp_w_tokens + temp_not_w_tokens

# %%
len(text_pre_tokens)
# Out:
# 29219

# %%
31843 + 905
# Out:
# 32748

# %%
count=0
for tok in toks:
    #re.sub(r'[0123456789:-.,]',"",tok)
    #re.sub(r"\W", "", tok, flags=re.I)
    tok.replace('percent',"")
    if (re.match(r'\W',tok)):
        tok = re.sub(r'\W',"",tok)
        tok = re.sub(r'[0-9]',"",tok)
        print(tok)
        tokens_new.append(tok)
        count +=1

print(count)
# Out:
# wwwcrohnscolitisfoundationorgassetspdfsunderstandingibdmedsnovpdf
# engineered
# medicare
# ll
# not
# ve
#
#
#
# cancergraceorgblogjimandlisa
# wwwncbinlmnihgovpubmed
# shiftmsmsreporters
# wwwfacebookcomshiftms
# wwwinstagramcomshiftdotms
# twittercomshiftms
#
# insidemystorycom
#
# wwwmstrustorgukazocrelizumab
# active
# _
# re
#
# wwwcancergovtypescolorectalpatientcolontreatmentpdq
# wwwncbinlmnihgovpmcarticlespmc
# cancergraceorglungtargetedtherapiesinlungcancerpatientforumpresentationsandhandouts
# wwwmstrustorgukaboutmsmstreatmentsmsdecisionsaid
# wwwgenecommediapressreleasesfdaacceptsgenentechssupplementalbiol
# ive
# dr
# multiplesclerosisresearchblogspotcomclinicspeakswi
# not
# wwwcghjournalorgarticles
#
#
#
# luxury
# sheerling
# cotton
# hot
# alexa
# try
# shower
# cooling
# squatty
#
#
#
#
# in
# anxiety
# without
# yet
# i
# then
# wwwmedpagetodaycommeetingc
# usually
#
#
# weaning
# positive
# wwwnovartiscomnewsmediareleasesnovartisannouncespositive
# wwwmultipleexperiencesorg
# multiplesclerosisresearchblogspotcomsupposetherewa
# wwwmstrustorgukazswallowing
# shiftms
#
# multiplesclerosisresearchblogspotcomcladribinemseffectivediseasehtml
#
#
#
# primary
# activating
#
# cancergraceorgtopictreatmentoptions
# wwwcancergovaboutcancertreatmentcampatientvitamincpdq
# also
# nccihnihgov
# wwwfdagov
# wwwhealiocomhematologyoncol
# cnw
# dale
# wwwcancerresearchukorghealthprofessionalcancerstatisticsstatisticsbycancertypenonhodgkinlymphoma
# does
# early
# but
#
# oh
# the
# specific
# black
# accumulationpresence
# skips
#
#
# multiplesclerosisresearchblogspotcomnewsspeakeagle
# cm
# many
# then
# multiplesclerosisnewstodayc
# cancergraceorgtopicnedformonthsstopgilotrifquestionstodrwest
# wwwmstrustorgukunderstandingmsmssymptomsandtreatmentsmsdecisions
# wwwncbinlmnihgovpubmed
# would
# genetic
# heidelberg
# wwwkargercomarticlefulltext
#
#
#
#
# multiplesclerosisresearchblogspotcomclinicspeakheadlineocrelizumabresultshtml
#
#
#
# three
#
#
#
#
#
# multiplesclerosisresearchblogspotcomclinicspeakisr
#
#
#
#
# dose
#
# blockers
#
# wwwjoslinorgnewslucentisproveseffectiveagainstproliferativediabeticretinopathyhtml
# communitymssocietyorgukforumsprimaryprogressivemscalling
# episode
#
# wwwfdagovnewseventsnewsroompressannouncementsucmhtm
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mutant
#
#
# sigh
# it
# unmanaged
# wwwastrazenecacommediacentrepressreleasesusfdaapprove
# wwwcancergovresearchncirolecancercentersfind
# wwwsitemanwustledu
#
#
#
#
#
# wwwmstrustorguknewsnewsaboutmsocrelizumabocrevusgetseuropeanlicencerelapsingandprimaryprogressivems
# wwwflickrcomphotosargonne
# the
#
# cancergraceorglungtagzykadia
# wwwhighbeamcomdocghtml
# cancergraceorgtopicchroniccoughanddifferenceofopinion
#
# onlinelibraryectrimscongresseuectrimsndnicoladestefanocladribineeffectonbrainvolumelossanditscorrelationhtml
# youtubeyk_jpki
# multiplesclerosisresearchblogspotcomcladribinemsef
# wwwbusinesswirecomnewshom
#
#
# multiplesclerosisresearchblogspotcomsupposethereistherapyformsthatishtml
#
#
# wwwmedianetcomaureleases
# doiorgs
# tm
# vs
# mymsaaorgnewsmsaafdaexpeditesreviewocrelizumab
#
#
# novartis
# everyone
# ers
# wwwlungcancerfoundationorgpatientsros
# wwwlungcancerfoundationorgpatientsrossurvey
# wwwcuretodaycomcommunitytoritomalialistenforzebrasarosstory
# per
# a
# b
# wwwnovartiscom
# twittercomnovartis
#
# wwwfrontiersinorgarticlesfimmufull
# chesty
#
# got
# just
# julie
# wwwcuretodaycomarticlesimmunotherapiesshowpromi
# wwwcancerorgcancerlungcancersmallcelldetailedgu
# wwwncbinlmnihgovpubmed
#
# endpoints
# smithonstockscomnorthwestbiotherapeuticsdcvaxlviewedthroughtheeyesofdrlindaliauleadinvestigatoronthephasetrialofdcvaxlnwbobuy
# journalssagepubcomdoiabs
# wwwmedicaltourisraelcomwp
# wwwhealthlinecomhealthnewsmswhyaremsdrugpricessohigh
# zombie
#
#
#
# this
# multiplesclerosisresearchblogspotcomsupposetherewastherapyforallhtml
# ve
#
# sorbelenerecommended
# woohoo
# failed
# wwwmedscapecomviewarticle
# wwwmedscapecomviewar
#
# wwwnaturecomismejjournalvnabsismejahtml
# wwwfascrsorgpatientsdiseaseconditioncrohnsdisease
# wwwnhsukconditionscrohnsdiseasepagescausesaspx
# wwwcdcgovibdibdepidemiologyhtm
# wwwncbinlmnihgovpmcarticlespmc
# giorgguidelinemanagementofcrohnsdiseaseinadults
# myclevelandclinicorghealtharticlescrohnsdisease
# wwwmedicalnewstodaycomarticlesphp
# reprogramming
# eat
# super
# ehealthme
# wwwehealthmecomdstysabripro
# ccsviinmsblogspotcom
# skin
# also
# ndandrd
# eye
# and
# each
# which
# as
# this
# since
# just
# gpsaid
# one
# this
# ive
# hopefully
# wwwfdagovmedwatch
# multiplesclerosisnewstodaycomhighmsactivityseenpatientafterconsecutiveuseimmunotherapiescasereport
# wwwncbinlmnihgovpubmed
# cancergraceorglungtopiclowalbuminlevels
# multiplesclerosisresearchb
# wwwyoutubecomwatch
# normal
# good
# has
# are
# triples
# in
# pml
# wwwncbinlmnihgovpubmed
# quote
# what
# outside
# fisfdagovhubstreamaaecdabfdfafd
# wwwmedicinesorgukemcima
# bpng
# wwwsciencedirectcomscienc
# journalslwwcomoncologytimesfulltextwarning_about_chemotherapy_afatinib_combinationaspx
#
# wwwncbinlmnihgovpubmed
# doiorgjournalpone
# hain
# any
# jpg
# report
# knock
# hot
# that
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# not
# barts
# is
# anticds
# ve
# wwwrituxancomhemhcp
# scroll
# diagnosed
# vit
# step
# permanently
# infusions
# subsequent
# the
# if
# he
#
# wwwinspirecomfightermjournalpdpdlisthesuperstarcheckpo
# after
# neuroimmunologywordpresscomrituximabvsocrelizumabinmultiplesclerosis
# whacked
# ride
# cause
# multiplesclerosisresearchblogspotcomofflabelcladrib
# every
# her
#
#
# smallcell
# wwwmedpagetodaycomclinicalcontextrheumatoidarthritis
# conventional
# wwwehealthmecomdsgilenyapancreatitis
# multiplesclerosisresearchblogspotcom
# increased
# my
# her
# she
# the
# really
#
# multum
# local
#
# rare
#
# multiplesclerosisnewstodaycomswitchingfromgilenyatorituximabformsmaybeproblemcasestudy
#
# keytruda
#
# on
# wwwcbsnewscomvideonewdrugprovideshopeforthosesufferingwithms
# wwwmultipleexperiencesorgocrelizumabocrevusversusrituximabrituxan
# cancergraceorgforumsindexphp
# fessed
# felt
# hold
# works
# tamingmultiplesclerosiscommultiplesclerosisseasonchangesarticlehtml
# multiplesclerosisnewstodaycomocrevussurveysideeffectsinfluencepatientsviewofitseffectiveness
# tinyurlcomgenefoocrevus
# dangerous
# and
# relapse
#
# wwwhealthnewsrevieworgfakebreakthroughfakenewsonephysicianresearcherstakeawaynewscoveragemsdrugocrevus
# wwwehealthmecomdstysabrideath
# chefarztfraude
# wwwmedpagetodaycomclinicalco
# wwwncbinlmnihgovpubmed
# msaboutcomodtreatmentsathe
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# blocker
# no
# wwwmssocietyorgukmsnewsnicesaysinitialnoocrelizumabrelapsingms
# wifi
# wwwresearchgatenetpublication_the_risk_of_cancer_in_inflammatory_bowel_disease_does_infliximab_contribute_to_cancer_risk
# social
#
# sorry
# or
# wwwncbinlmnihgovpmcarticlespmc
# just
# reread
# inlaw
# after
# wwwnytimescombusin
# but
# wwwiomedumediamarch
# wwwmstrustorgukazexercise
# mutationpositive
#
# multiplesclerosisresearchorg
# rebounds
# cancergraceorglungtagimmunotherapycombinations
# cancergraceorghnsccascotreatingheadandneckcancerusingimmunotherapyasfirstlinetreatmentandincombinations
# cancergraceorglunggcvl_lu_immunotherapy_combinations_future_treating_lung_cancer
# ocular
# problems
#
#
# so
# considering
# eurlexeuropaeulegalcontentenauto
# m
#
# insightsovidcomcrossref
#
# cancergraceorgtopicsomequestionslungcancer
# is
# wwwtrademarkiacomocrevushtml
# pneumonitis
# cancergraceorgsearchresults
# cancergraceorglungimprecisionmedicinewhykeytrudapembrolizumabchemoforpdlnsclcisntreadyforprimetime
# while
#
# inflammatoryboweldiseasenettreatmentmedications
# mary
#
# selfhackedcomblogdietnut
# eye
# wwwemaeuropaeudocsen_gbdocument_libraryepar__product_informationhumanwcpdf
# facebookcomgroups
# clinicaltrialsgovctshownct
# wwwrtogorgnewstabidarticletypearticleviewarticleidavoidanceofthehippocampusisshowntopreservememoryaspx
# wwwimsmporgcontentocrelizumabfdaapprovedtreatmentms
# our
# and
# now
# not
# appjamanetworkcom
# wwwniceorgukguidancegidtadocumentsappraisalconsult
# sd
#
#
#
#
#
#
#
# wwwcnncomhealthmsdrugdaclizumabpulledbnindexhtml
# multiplesclerosisresearchblogspotcompmlwarningoncladribinebymhrahashtml
# doiorg
# cancergraceorgcancerclintrialsramalingampt
# cancergraceorgcancerhowareclintrialsdeveloped
# cancergraceorgcancerramalingamclintrialspt
# wwwaaoorgeyehealthdiseasesavastineylealucentisdifference
# treatment
# fisfdagovsenseappefdcfefcbaasheetbeebabbebstateanalysis
# wwwocrevuscompatientsafetyhtml
# wwwpharmausnovartiscomnewsmediareleasesnovartisannouncesfdafilingacceptancesiponimodbaffirstandonlyoral
# wwwgofundmecomcruo
#
#
# there
#
#
# wwwmymsaaorgaboutmssources
# wwwfemagovregionaloperationsstateofficesandagenciesemergencymanagement
# article
# wwwumcororgumcorresourcesnewsstoriesoctoberhowtohelpdothisnotthat
# wwwicgovmediaaspx
# wwwstatenjusnjoem
# disastercentercomnewjersynewjersyhtm
# wwwdhsesnygovoem
# disastercentercomnewyorknewyorkhtm
# wwwnyredcrossorg
# wwwfoodbanknycorg
# urination
# multiplesclerosisresearchblogspotcomresearchspeakrituxumabvsfingolimodhtml
# multiple
# wwwthestreetcomstorycelgenemultiplesclerosispillsucceedsinfirstlatestageclinicaltrialhtml
# multiplesclerosisresearchblogspotcomhsctinprogressivemshtml
#
#
#
#
#
#
#
# msddjournalbiomedcentralco
#
#
#
#
#
#
#
#
# wwwemaeuropaeuemaindexjsp
# lbs
# mg
#
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwpubmedcentralnihgovpicrenderfcgi
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwfdagovdrugsdrugsafetypostmarketdrugsafetyinformationforpatientsandprovidersdrugsafetyinformationforheathcareprofessionalsucmhtm
# wwwfdagovdrugsdrugsafetypostmarketdrugsafetyinformationforpatientsandprovidersucmhtm
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwfdagovdownloadsdrugsdrugsafetypostmarketdrugsafetyinformationforpatientsandprovidersucmpdf
# wwwfdagovdrugsdrugsafetyucmhtm
# wwwfdagovdrugsdrugsafetyucmhtm
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
#
#
# mutated
#
# cancergraceorglungtagoligoprogression
# â
# wet
# neutralizing
# wwwdiabeticretinopathyorguklucentispatientsdrhtm
# out
# jennifer
# wwwucsfedunewsnewmultiplesclerosisdrugocrelizumabcouldhaltdisease
# wwwdavidscampathstoryorgindexhtml
# wwwjustgivingcomfundraisingmarkseacombe
# tedxchelmsfordcomworksellenmarshall
# wwwexpresscouknewsukmultiplesclerosisdrugocrelizumabtreatmentbritaingavingiovannoninickrijke
#
# wwwbusinesswirecomnewshomeen
# wwwbusinesswirecomnewshomeen
# in
# when
# ointment
# steroid
# following
# patients
# steroid
# methodsfifteen
# aircharitynetworkorgrequestaflight
# lifelinepilotsorg
# wwwcorpangelnetworkorg
# mercymedicalorg
# wwwlazarexorg
# embenkickscancerwordpresscom
# wpvcueduhemeoncfellowshipwpcontentuploadssiteskeynotecarbopemetrexedpembrolizumabinadvancednonsquamousnsclclancetpdf
#
#
# line
#
#
#
#
# owlykcbtwdbn
# glucose
# positron
#
#
#
#
# wwwinspirecomgroupsamericanlungassociationlungcancersurvivorsdiscussionduravalumabimfinzipatientssupportgroup
# wwwcancercaencancerinformationcancertypelungtreatmentchemotherapy
#
# outside
#
#
#
# clinicaltrialsgovctshownct
#
#
#
# antibodies
# approved
# γinduced
#
# thayruhpee
# antihjen
# lihneeer
# gleeohmuh
# wwwcancergovtypessofttissuesarcomapatientrhabdomyosarcomatreatmentpdq
#
#
#
#
#
#
# nccnorg
# clinicaltrialsgovctshownct
# clincancerresaacrjournalsorgcontentfull
# scohn
# linkspringercoms
# newsroomregeneroncom
# twittercomregeneron
# dk
# driven
# y
#
# adventuresinlivingterminallyopti
# has
# born
# patient
# health
# health
# wwwcancergovnewseventscancercurrentsbloggenomicprofilingtestscancer
# wwwcancergovnewseventscancercurrentsblogearlystagelungcancerbiomarker
# nccn
# wwwkalturacomindexphpextwidgetpreviewpartner_iduiconf_identry_id_mlovembediframe
# lol
# limited
# roscancercom
# wwwclinicaltrialsgovctshownct
#
#
#
#
#
#
# much
# wwwmskccorgexperiencebecomepatientappointment
# multiplesclerosisresearchblogspotcomteamghelpsdeveloplicenceddrughtml
# wwwmedicinesorgukemcproductsmpc
#
# wwwmstrustorgukazmavencladcladribine
#
#
#
#
#
#
#
#
# mutation
# socialized
# journalslwwcomcogastroenterologyfulltextcheckpoint_inhi
# for
# use
# onlinelibrarywileycomdoipdfapt
#
#
# wwwncbinlmnihgovpmcarticlespmc
# hopefully
# clinicaltrialsgovshownct
#
#
#
#
# when
# paclitaxel
#
# wwwtechnologynetworkscomcancerresearchnewsunstablechromosomesincreaseriskofcancerreturning
#
# cancergraceorgtopicmedipage
# url
# we
# immunotherapy
# carboplatin
#
# moonface
# weight
# swelling
# bad
# brain
# dizziness
# increased
# irritability
# no
# wwwncbinlmnihgovpubmed
# amzntohgirt
# wwwemaeuropaeumedicineshumaneparavastin
# wwwemaeuropaeumedicineshumaneparkeytruda
# you
# will
#
# injection
# this
# mtx
# wwwncbinlmnihgovpubmed
#
#
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
#
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwncbinlmnihgovpubmed
# wwwaccessdatafdagovdrugsatfda_docsndaorigssumrpdf
# antagonist
#
# x
#
#
#
#
#
# brodalumab
# hematology
# to
# backs
# thicken
# crosssectional
# pinched
# hardening
# sludge
# clears
# proved
# squashing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# timolol
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# is
# what
# afatinib
# helix
# mutation
# wwwinspirecommdaxys
# blood
# term
#
#
#
#
#
# prnewswire
#
#
# wwwpmlivecompharma_newspfizer_files_thirdgen_alk_inhibitor_for_lung_cancer_
# wwwcancertherapyadvisorcomlungcancernonsmallcelllungcancercrizotinibalkbrainmetastasesarticle
#
# you
# today
# abby
# is
# what
#
# could
# but
# limod
# notes
# wwwsciencedirectcomtopicsneurosciencecytokines
# wwwsciencedirectcomtopicsneuroscienceinterleukin
# wwwsciencedirectcomtopicsimmunologyandmicrobiologytumornecrosisfactoralpha
# wwwbioradantibodiescomimmunoglobulinantibodyhtml
# wwwcrohnscolitisfoundationorgresourcesimmunomodulatorshtml
# seuwestamazonawscomfilescrohnsandcolitisorgukpublicationsazathioprine_ed_b__feb_pdf
# wwwncbinlmnihgovpmcarticlespmc
# wwwncbinlmnihgovpmcarticlespmc
# wwwncbinlmnihgovpubmed
# wwwuptodatecomcontentspharmacologyofcyclosporineandtacrolimus
# wwwcancerorgtreatmenttreatmentsandsideeffectstreatmenttypesimmunotherapymonoclonalantibodieshtml
# wwwuptodatecomcontentstumornecrosisfactoralphainhibitorsinductionofantibodiesautoantibodiesandautoimmunediseases
# wwwremicadecomcrohnsdiseasehowdoesremicadework
# wwwmerckcomproductusapi_circularsrrenflexisrenflexis_pipdf
# labelingpfizercomshowlabelingaspx
# wwwhumiracomcrohnshowhumiraworksforcrohns
# wwwcimziacomlivingwithcd
# wwwsimponicom
# wwwtysabrihcpcomen_ushomeaboutmechanismofactionhtml
# wwwaccessdatafdagovdrugsatfda_docslabelslblpdf
# wwwentyviohcpcommechanismofaction
# wwwstelarahcpcomcrohnsdiseasemechanismofaction
# shrug
# rich
# ad
# extracellular
# dependent
# stimulated
# cdmd
# extraskeletal
# wwwcancergovtypessofttissuesarcomapatientchildsofttissuetreatmentpdq
# reduced
# is
# two
# ipi
# bill
# ascopubsorgdoiabsjco_suppl
# wwwcanceractivecomarticlemelanomaandskincancersymptomst
#
# based
# they
# what
# nivolumab
# caused
# nanopore
# tumors
#
# investoralimerasciencescomindexphpnewsreleasesnewsreleasedetailsalimerasciencesreceivesacceptancefilingobtainapproval
# eyepointpharmacompipeline
#
# cancergraceorglungacquiredresistanceinlungcancerpatientforumvideos
#
#
#
# grin
#
# and
# wwwgovbccaassetsgovhealthhealthdrugcoveragepharmacarenewslettersnewspdf
# wwwmerckcastaticpdfrenflexispm_epdf
# wwwcrohnsandcolitiscacrohns_and_colitisdocumentsreportsccfcibdimpactreportpdf
# wwwnaturecomarticlesajgpdf
# crohnsandcolitiscaaboutcrohnscolitisareyouatrisk
# wwwarthritiscaaboutarthritisarthritistypes
# typesinflammatoryarthritis
# typesrheumatoidarthritis
# rearranged
# associated
# m
# m
# originator
# m
# m
# best
# wwwcancergovtypeslungpatientnonsmallcelllungtreatmentpdq
#
#
#
#
# wwwthediabetescouncilcomultimateguidetotheactesteverythingyouneedtoknow
# wwwaaoorgeyehealthtreatmentswhatisopticalcoherencetomography
#
# wwwdiabeticretinopathyorgukretinopathyprogressionhtm
# wwwdiabeticretinopathyorgukdiabetic_retinopathy_mechhtml
#
#
# agerelated
# eye
# clean
#
#
#
#
#
#
#
#
# wwwlungcancerfoundationorgpatientsrostrialsandtreatments
# omics
# wwwejogorgarticles
#
#
#
#
# flame
# homing
# look
#
# complications
#
# chemsisnlmnihgovchemidpluschemidheavyjsp
#
#
#
#
# forumslungevityorgforumdiscussionforums
#
#
# 905

# %%
tokens_new
# Out:
# ['wwwcrohnscolitisfoundationorgassetspdfsunderstandingibdmedsnovpdf',
#  'engineered',
#  'medicare',
#  'll',
#  'not',
#  've',
#  '',
#  '',
#  '',
#  'cancergraceorgblogjimandlisa',
#  'wwwncbinlmnihgovpubmed28391420',
#  'shiftmsmsreporters',
#  'wwwfacebookcomshiftms',
#  'wwwinstagramcomshiftdotms',
#  'twittercomshiftms',
#  '',
#  'insidemystorycom',
#  '',
#  'wwwmstrustorgukazocrelizumab',
#  'active',
#  '_',
#  're',
#  '24',
#  'wwwcancergovtypescolorectalpatientcolontreatmentpdq',
#  'wwwncbinlmnihgovpmcarticlespmc5401676',
#  'cancergraceorglung20170928targetedtherapiesinlungcancerpatientforum2017presentationsandhandouts',
#  'wwwmstrustorgukaboutmsmstreatmentsmsdecisionsaid',
#  'wwwgenecommediapressreleases1477320190116fdaacceptsgenentechssupplementalbiol',
#  'ive',
#  'dr',
#  'multiplesclerosisresearchblogspotcom201405clinicspeakswi',
#  'not',
#  'wwwcghjournalorgarticles15423565',
#  '05',
#  '15',
#  '10',
#  'luxury',
#  'sheerling',
#  'cotton',
#  'hot',
#  'alexa',
#  'try',
#  'shower',
#  'cooling',
#  'squatty',
#  '00001',
#  '0001',
#  '123742',
#  '12359',
#  'in',
#  'anxiety',
#  'without',
#  'yet',
#  'i',
#  'then',
#  'wwwmedpagetodaycommeetingc',
#  'usually',
#  '04',
#  '17',
#  'weaning',
#  'positive',
#  'wwwnovartiscomnewsmediareleasesnovartisannouncespositive',
#  'wwwmultipleexperiencesorg',
#  'multiplesclerosisresearchblogspotcom201601supposetherewa',
#  'wwwmstrustorgukazswallowing',
#  'shiftms',
#  '',
#  'multiplesclerosisresearchblogspotcom201606cladribine4mseffectivediseasehtml',
#  '172183',
#  '11171126',
#  '10981100',
#  'primary',
#  'activating',
#  '',
#  'cancergraceorgtopictreatmentoptions2',
#  'wwwcancergovaboutcancertreatmentcampatientvitamincpdq',
#  'also',
#  'nccihnihgov',
#  'wwwfdagov',
#  'wwwhealiocomhematologyoncol',
#  'cnw',
#  'dale',
#  'wwwcancerresearchukorghealthprofessionalcancerstatisticsstatisticsbycancertypenonhodgkinlymphoma',
#  'does',
#  'early',
#  'but',
#  '',
#  'oh',
#  'the',
#  'specific',
#  'black',
#  'accumulationpresence',
#  'skips',
#  '120',
#  '20',
#  'multiplesclerosisresearchblogspotcom201703newsspeakeagle',
#  '6cm',
#  'many',
#  'then',
#  'multiplesclerosisnewstodayc',
#  'cancergraceorgtopicnedfor21monthsstopgilotrif2questionstodrwest',
#  'wwwmstrustorgukunderstandingmsmssymptomsandtreatmentsmsdecisions',
#  'wwwncbinlmnihgovpubmed30677733',
#  'would',
#  'genetic',
#  'heidelberg',
#  'wwwkargercomarticlefulltext492322',
#  '85',
#  '79',
#  '95',
#  '72',
#  'multiplesclerosisresearchblogspotcom201510clinicspeakheadlineocrelizumabresultshtml',
#  '375',
#  '4',
#  '53',
#  'three',
#  '060',
#  '50',
#  '15',
#  '022',
#  '003',
#  'multiplesclerosisresearchblogspotcom201509clinicspeakisr',
#  '12',
#  '40',
#  '60',
#  '30',
#  'dose',
#  '15',
#  'blockers',
#  '20',
#  'wwwjoslinorgnewslucentisproveseffectiveagainstproliferativediabeticretinopathyhtml',
#  'communitymssocietyorgukforumsprimaryprogressivemscalling',
#  'episode',
#  '10561065',
#  'wwwfdagovnewseventsnewsroompressannouncementsucm466413htm',
#  '00825',
#  '001',
#  '62',
#  '73',
#  '82',
#  '71',
#  '20',
#  '16',
#  '86',
#  '22',
#  '10',
#  '99',
#  '0008',
#  '07',
#  '004',
#  '0005',
#  '0002',
#  'mutant',
#  '2055217318778610',
#  '2055217318777894',
#  'sigh',
#  'it',
#  'unmanaged',
#  'wwwastrazenecacommediacentrepressreleases2018usfdaapprove',
#  'wwwcancergovresearchncirolecancercentersfind',
#  'wwwsitemanwustledu',
#  '45',
#  '30',
#  '55',
#  '90',
#  '25',
#  'wwwmstrustorguknewsnewsaboutmsocrelizumabocrevusgetseuropeanlicencerelapsingandprimaryprogressivems',
#  'wwwflickrcomphotosargonne3974983988',
#  'the',
#  '',
#  'cancergraceorglungtagzykadia',
#  'wwwhighbeamcomdoc1g1470081283html',
#  'cancergraceorgtopicchroniccoughanddifferenceofopinion',
#  '50',
#  'onlinelibraryectrimscongresseuectrims201632nd146337nicoladestefanocladribineeffectonbrainvolumelossanditscorrelationhtml',
#  'youtubeyk7_jpk33i4',
#  'multiplesclerosisresearchblogspotcom201606cladribine4msef',
#  'wwwbusinesswirecomnewshom',
#  '86',
#  '26',
#  'multiplesclerosisresearchblogspotcom201510supposethereistherapyformsthatishtml',
#  '05',
#  '24',
#  'wwwmedianetcomaureleases127433',
#  'doiorg101186s1288301707945',
#  't790m',
#  'vs',
#  'mymsaaorgnewsmsaa1380fdaexpeditesreviewocrelizumab',
#  '03',
#  '',
#  'novartis',
#  'everyone',
#  'ers',
#  'wwwlungcancerfoundationorgpatientsros1',
#  'wwwlungcancerfoundationorgpatientsros1survey',
#  'wwwcuretodaycomcommunitytoritomalia201607listenforzebrasaros1story',
#  'per',
#  '1a',
#  '1b',
#  'wwwnovartiscom',
#  'twittercomnovartis',
#  '41',
#  'wwwfrontiersinorgarticles103389fimmu201300438full',
#  'chesty',
#  '04',
#  'got',
#  'just',
#  'julie',
#  'wwwcuretodaycomarticlesimmunotherapiesshowpromi',
#  'wwwcancerorgcancerlungcancersmallcelldetailedgu',
#  'wwwncbinlmnihgovpubmed27206905',
#  '50',
#  'endpoints',
#  'smithonstockscomnorthwestbiotherapeuticsdcvaxlviewedthroughtheeyesofdrlindaliauleadinvestigatoronthephase3trialofdcvaxlnwbo035buy',
#  'journalssagepubcomdoiabs',
#  'wwwmedicaltourisraelcomwp',
#  'wwwhealthlinecomhealthnewsmswhyaremsdrugpricessohigh071913',
#  'zombie',
#  '699710',
#  '71121',
#  '18590',
#  'this',
#  'multiplesclerosisresearchblogspotcom201601supposetherewastherapyforallhtml',
#  've',
#  '8',
#  'sorbelenerecommended',
#  'woohoo',
#  'failed',
#  'wwwmedscapecomviewarticle906837',
#  'wwwmedscapecomviewar',
#  '20092018',
#  'wwwnaturecomismejjournalv1n5absismej200752ahtml',
#  'wwwfascrsorgpatientsdiseaseconditioncrohnsdisease0',
#  'wwwnhsukconditionscrohnsdiseasepagescausesaspx',
#  'wwwcdcgovibdibdepidemiologyhtm',
#  'wwwncbinlmnihgovpmcarticlespmc4087458',
#  'giorgguidelinemanagementofcrohnsdiseaseinadults',
#  'myclevelandclinicorghealtharticlescrohnsdisease',
#  'wwwmedicalnewstodaycomarticles151620php',
#  'reprogramming',
#  'eat',
#  'super',
#  'ehealthme',
#  'wwwehealthmecomdstysabripro',
#  'ccsviinmsblogspotcom',
#  'skin',
#  'also',
#  '2ndand3rd',
#  'eye',
#  'and',
#  'each',
#  'which',
#  'as',
#  'this',
#  'since',
#  'just',
#  'gpsaid',
#  'one',
#  'this',
#  'ive',
#  'hopefully',
#  'wwwfdagovmedwatch',
#  'multiplesclerosisnewstodaycom20180821highmsactivityseenpatientafterconsecutiveuseimmunotherapiescasereport',
#  'wwwncbinlmnihgovpubmed30114625',
#  'cancergraceorglungtopiclowalbuminlevels',
#  'multiplesclerosisresearchb',
#  'wwwyoutubecomwatch',
#  'normal',
#  'good',
#  'has',
#  'are',
#  'triples',
#  'in',
#  'pml',
#  'wwwncbinlmnihgovpubmed23925759',
#  'quote',
#  'what',
#  'outside',
#  'fisfdagovhubstreamaaec8d41520143ab809f3063750dfafd',
#  'wwwmedicinesorgukemcima',
#  '2143576bpng',
#  'wwwsciencedirectcomscienc',
#  'journalslwwcomoncologytimesfulltext201504100warning_about_chemotherapy_afatinib_combination3aspx',
#  '388397',
#  'wwwncbinlmnihgovpubmed18574932',
#  'doiorg101371journalpone0190425',
#  'hain',
#  'any',
#  'jpg',
#  'report',
#  'knock',
#  'hot',
#  'that',
#  'wwwncbinlmnihgovpubmed23868420',
#  'wwwncbinlmnihgovpubmed23913509',
#  'not',
#  'barts',
#  'is',
#  'anticd20s',
#  've',
#  'wwwrituxancomhemhcp',
#  'scroll',
#  'diagnosed',
#  'vit',
#  'step',
#  'permanently',
#  'infusions',
#  'subsequent',
#  'the',
#  'if',
#  'he',
#  '',
#  'wwwinspirecomfightermjournalpd1pdl1isthesuperstarcheckpo',
#  'after',
#  'neuroimmunologywordpresscom20111103rituximabvsocrelizumabinmultiplesclerosis',
#  'whacked',
#  'ride',
#  'cause',
#  'multiplesclerosisresearchblogspotcom201410offlabelcladrib',
#  'every',
#  'her',
#  '357',
#  '600',
#  'smallcell',
#  'wwwmedpagetodaycomclinicalcontextrheumatoidarthritis26391',
#  'conventional',
#  'wwwehealthmecomdsgilenyapancreatitis',
#  'multiplesclerosisresearchblogspotcom',
#  'increased',
#  'my',
#  'her',
#  'she',
#  'the',
#  'really',
#  '50',
#  'multum',
#  'local',
#  '',
#  'rare',
#  '06',
#  'multiplesclerosisnewstodaycom20180823switchingfromgilenyatorituximabformsmaybeproblemcasestudy',
#  '1800',
#  'keytruda',
#  '02',
#  'on',
#  'wwwcbsnewscomvideonewdrugprovideshopeforthosesufferingwithms',
#  'wwwmultipleexperiencesorg20170628ocrelizumabocrevusversusrituximabrituxan',
#  'cancergraceorgforumsindexphp',
#  'fessed',
#  'felt',
#  'hold',
#  'works',
#  'tamingmultiplesclerosiscommultiplesclerosisseasonchangesarticlehtml',
#  'multiplesclerosisnewstodaycom20180416ocrevussurveysideeffectsinfluencepatientsviewofitseffectiveness',
#  'tinyurlcomgenefoocrevus',
#  'dangerous',
#  'and',
#  'relapse',
#  '3922',
#  'wwwhealthnewsrevieworg201704fakebreakthroughfakenewsonephysicianresearcherstakeawaynewscoveragemsdrugocrevus',
#  'wwwehealthmecomdstysabrideath',
#  'chefarztfraude',
#  'wwwmedpagetodaycomclinicalco',
#  'wwwncbinlmnihgovpubmed23100404',
#  'msaboutcomodtreatmentsathe',
#  'wwwncbinlmnihgovpubmed23338729',
#  'wwwncbinlmnihgovpubmed23252596',
#  'blocker',
#  'no',
#  'wwwmssocietyorgukmsnews201804nicesaysinitialnoocrelizumabrelapsingms',
#  'wifi',
#  'wwwresearchgatenetpublication318146352_the_risk_of_cancer_in_inflammatory_bowel_disease_does_infliximab_contribute_to_cancer_risk',
#  'social',
#  '3500',
#  'sorry',
#  'or',
#  'wwwncbinlmnihgovpmcarticlespmc5869778',
#  'just',
#  'reread',
#  'inlaw',
#  'after',
#  'wwwnytimescom20050301busin',
#  'but',
#  'wwwiomedumediamarch',
#  'wwwmstrustorgukazexercise',
#  'mutationpositive',
#  '300',
#  'multiplesclerosisresearchorg',
#  'rebounds',
#  'cancergraceorglungtagimmunotherapycombinations',
#  'cancergraceorghnscc20160802asco2016treatingheadandneckcancerusingimmunotherapyasfirstlinetreatmentandincombinations',
#  'cancergraceorglung20151208gcvl_lu_immunotherapy_combinations_future_treating_lung_cancer',
#  'ocular',
#  'problems',
#  '70000',
#  '35000000',
#  'so',
#  'considering',
#  'eurlexeuropaeulegalcontentenauto',
#  '84m',
#  '02',
#  'insightsovidcomcrossref',
#  '800',
#  'cancergraceorgtopicsomequestionslungcancer',
#  'is',
#  'wwwtrademarkiacomocrevus86205182html',
#  'pneumonitis',
#  'cancergraceorgsearchresults',
#  'cancergraceorglung20170112imprecisionmedicinewhykeytrudapembrolizumabchemoforpdl1nsclcisntreadyforprimetime',
#  'while',
#  '0025',
#  'inflammatoryboweldiseasenettreatmentmedications',
#  'mary',
#  '47',
#  'selfhackedcomblogdietnut',
#  'eye',
#  'wwwemaeuropaeudocsen_gbdocument_libraryepar__product_informationhuman002202wc500104528pdf',
#  'facebookcomgroups653313891487070',
#  'clinicaltrialsgovct2shownct01227954',
#  'wwwrtogorgnewstabid72articletypearticleviewarticleid73avoidanceofthehippocampusisshowntopreservememoryaspx',
#  'wwwimsmporgcontentocrelizumabfdaapprovedtreatmentms',
#  'our',
#  'and',
#  'now',
#  'not',
#  'appjamanetworkcom',
#  'wwwniceorgukguidancegidta10153documentsappraisalconsult',
#  'sd',
#  '63',
#  '01',
#  '06',
#  '02',
#  '99',
#  '86',
#  '80',
#  'wwwcnncom20180302healthmsdrugdaclizumabpulledbnindexhtml',
#  'multiplesclerosisresearchblogspotcom201712pmlwarningoncladribinebymhrahashtml',
#  'doiorg',
#  'cancergraceorgcancer10120130106clintrialsramalingampt1',
#  'cancergraceorgcancer10120130118howareclintrialsdeveloped',
#  'cancergraceorgcancer10120130127ramalingamclintrialspt3',
#  'wwwaaoorgeyehealthdiseasesavastineylealucentisdifference',
#  'treatment',
#  'fisfdagovsenseapp777e9f4d0cf8448e8068f564c31baa25sheet45beeb7430ab46be82675756582633b4stateanalysis',
#  'wwwocrevuscompatientsafetyhtml',
#  'wwwpharmausnovartiscomnewsmediareleasesnovartisannouncesfdafilingacceptancesiponimodbaf312firstandonlyoral',
#  'wwwgofundmecom6c89ruo',
#  '100000',
#  '60000',
#  'there',
#  '01',
#  '02',
#  'wwwmymsaaorgaboutmssources',
#  'wwwfemagovregionaloperationsstateofficesandagenciesemergencymanagement',
#  'article',
#  'wwwumcororgumcorresourcesnewsstories2012octoberhowtohelpdothisnotthat',
#  'wwwic3govmedia2011110311aspx',
#  'wwwstatenjusnjoem',
#  'disastercentercomnewjersynewjersyhtm',
#  'wwwdhsesnygovoem',
#  'disastercentercomnewyorknewyorkhtm',
#  'wwwnyredcrossorg',
#  'wwwfoodbanknycorg',
#  'urination',
#  'multiplesclerosisresearchblogspotcom201604researchspeakrituxumabvsfingolimodhtml',
#  'multiple',
#  'wwwthestreetcomstory140065481celgenemultiplesclerosispillsucceedsinfirstlatestageclinicaltrialhtml',
#  'multiplesclerosisresearchblogspotcom201706hsctinprogressivemshtml',
#  '014',
#  '003',
#  '05001',
#  '622',
#  '015',
#  '09',
#  '12',
#  'msddjournalbiomedcentralco',
#  '21222133',
#  '2029',
#  '585602',
#  '141147',
#  '591600',
#  '572573',
#  '416',
#  '204216',
#  'wwwemaeuropaeuemaindexjsp',
#  '10lbs',
#  '5mg',
#  '254',
#  'wwwncbinlmnihgovpubmed12528101',
#  'wwwncbinlmnihgovpubmed7779114',
#  'wwwncbinlmnihgovpubmed8507213',
#  'wwwncbinlmnihgovpubmed9751088',
#  'wwwncbinlmnihgovpubmed8633113',
#  'wwwncbinlmnihgovpubmed12379628',
#  'wwwpubmedcentralnihgovpicrenderfcgi',
#  'wwwncbinlmnihgovpubmed15146409',
#  'wwwncbinlmnihgovpubmed16200601',
#  'wwwncbinlmnihgovpubmed16802350',
#  'wwwfdagovdrugsdrugsafetypostmarketdrugsafetyinformationforpatientsandprovidersdrugsafetyinformationforheathcareprofessionalsucm174474htm',
#  'wwwfdagovdrugsdrugsafetypostmarketdrugsafetyinformationforpatientsandprovidersucm124185htm',
#  'wwwncbinlmnihgovpubmed18716298',
#  'wwwncbinlmnihgovpubmed9321530',
#  'wwwfdagovdownloadsdrugsdrugsafetypostmarketdrugsafetyinformationforpatientsandprovidersucm224377pdf',
#  'wwwfdagovdrugsdrugsafetyucm270849htm',
#  'wwwfdagovdrugsdrugsafetyucm250913htm',
#  'wwwncbinlmnihgovpubmed21083543',
#  'wwwncbinlmnihgovpubmed21209123',
#  'wwwncbinlmnihgovpubmed22062358',
#  'wwwncbinlmnihgovpubmed23665965',
#  '066',
#  '011',
#  'mutated',
#  '',
#  'cancergraceorglungtagoligoprogression',
#  'â',
#  'wet',
#  'neutralizing',
#  'wwwdiabeticretinopathyorguklucentispatientsdrhtm',
#  'out',
#  'jennifer',
#  'wwwucsfedunews201703406296newmultiplesclerosisdrugocrelizumabcouldhaltdisease',
#  'wwwdavidscampathstoryorgindexhtml',
#  'wwwjustgivingcomfundraisingmarkseacombe1',
#  'tedxchelmsfordcomworksellenmarshall',
#  'wwwexpresscouknewsuk610907multiplesclerosisdrugocrelizumabtreatmentbritaingavingiovannoninickrijke',
#  '0005',
#  'wwwbusinesswirecomnewshome20190117005165en',
#  'wwwbusinesswirecomnewshome20190117005165en',
#  'in',
#  'when',
#  'ointment',
#  'steroid',
#  'following',
#  'patients',
#  'steroid',
#  'methodsfifteen',
#  'aircharitynetworkorgrequestaflight',
#  'lifelinepilotsorg',
#  'wwwcorpangelnetworkorg',
#  'mercymedicalorg',
#  'wwwlazarexorg',
#  'embenkickscancerwordpresscom',
#  'wpvcueduhemeoncfellowshipwpcontentuploadssites3982201708keynote021carbopemetrexedpembrolizumabinadvancednonsquamousnsclc2016lancetpdf',
#  '189',
#  '227',
#  'line',
#  '029',
#  '011',
#  '022',
#  '02',
#  'owlykcbt306wdbn',
#  'glucose',
#  'positron',
#  '001',
#  '0003',
#  '0020',
#  '0018',
#  'wwwinspirecomgroupsamericanlungassociationlungcancersurvivorsdiscussionduravalumabimfinzipatientssupportgroup',
#  'wwwcancercaencancerinformationcancertypelungtreatmentchemotherapy',
#  '22833',
#  'outside',
#  '709',
#  '508',
#  '092',
#  'clinicaltrialsgovct2shownct02349633',
#  '002',
#  '537',
#  '6',
#  'antibodies',
#  'approved',
#  'γinduced',
#  '023',
#  'thayruhpee',
#  'antihjen',
#  'lihneeer',
#  'gleeohmuh',
#  'wwwcancergovtypessofttissuesarcomapatientrhabdomyosarcomatreatmentpdq',
#  '12',
#  '50',
#  '10',
#  '80',
#  '459465',
#  '976983',
#  'nccnorg',
#  'clinicaltrialsgovct2shownct02659059',
#  'clincancerresaacrjournalsorgcontent2092424full',
#  'scohn',
#  'linkspringercom101007s1232501808480',
#  'newsroomregeneroncom',
#  'twittercomregeneron',
#  'dk',
#  'driven',
#  'y393',
#  '001',
#  'adventuresinlivingterminallyopti',
#  'has',
#  'born',
#  'patient',
#  'health',
#  'health',
#  'wwwcancergovnewseventscancercurrentsblog2017genomicprofilingtestscancer',
#  'wwwcancergovnewseventscancercurrentsblog2019earlystagelungcancerbiomarker',
#  'nccn',
#  'wwwkalturacomindexphpextwidgetpreviewpartner_id2207941uiconf_id40195191entry_id1_7m16l2ovembediframe',
#  'lol',
#  'limited',
#  'ros1cancercom',
#  'wwwclinicaltrialsgovct2shownct02034981',
#  '4000',
#  '2400',
#  '2900',
#  '4500',
#  '700',
#  '1200',
#  'much',
#  'wwwmskccorgexperiencebecomepatientappointment',
#  'multiplesclerosisresearchblogspotcom201708teamghelpsdeveloplicenceddrughtml',
#  'wwwmedicinesorgukemcproduct1438smpc',
#  '',
#  'wwwmstrustorgukazmavencladcladribine',
#  '19561957',
#  '459469',
#  '28894',
#  '22302237',
#  '325',
#  '261',
#  '75',
#  '01',
#  'mutation',
#  'socialized',
#  'journalslwwcomcogastroenterologyfulltext201811000checkpoint_inhi',
#  'for',
#  'use',
#  'onlinelibrarywileycomdoipdf101111apt13847',
#  '40',
#  '30',
#  'wwwncbinlmnihgovpmcarticlespmc4872064',
#  'hopefully',
#  'clinicaltrialsgovshownct02888743',
#  '80',
#  '0095',
#  '007',
#  '02',
#  'when',
#  'paclitaxel',
#  '056',
#  'wwwtechnologynetworkscomcancerresearchnewsunstablechromosomesincreaseriskofcancerreturning288099',
#  '005',
#  'cancergraceorgtopicmedi4736page3',
#  'url',
#  'we',
#  'immunotherapy',
#  'carboplatin',
#  '25',
#  'moonface',
#  'weight',
#  'swelling',
#  'bad',
#  'brain',
#  'dizziness',
#  'increased',
#  'irritability',
#  'no',
#  'wwwncbinlmnihgovpubmed30644981',
#  'amznto2hgi0rt',
#  'wwwemaeuropaeumedicineshumaneparavastin',
#  'wwwemaeuropaeumedicineshumaneparkeytruda',
#  'you',
#  'will',
#  '',
#  'injection',
#  'this',
#  'mtx',
#  'wwwncbinlmnihgovpubmed30536638',
#  '24',
#  '65',
#  'wwwncbinlmnihgovpubmed24842416',
#  'wwwncbinlmnihgovpubmed24799843',
#  'wwwncbinlmnihgovpubmed15958805',
#  'wwwncbinlmnihgovpubmed23964932',
#  'wwwncbinlmnihgovpubmed24899819',
#  'wwwncbinlmnihgovpubmed23723689',
#  'wwwncbinlmnihgovpubmed23046232',
#  'wwwncbinlmnihgovpubmed25211302',
#  'wwwncbinlmnihgovpubmed21180594',
#  'wwwncbinlmnihgovpubmed23964933',
#  '124',
#  'wwwncbinlmnihgovpubmed24859203',
#  'wwwncbinlmnihgovpubmed25309060',
#  'wwwncbinlmnihgovpubmed19509315',
#  'wwwncbinlmnihgovpubmed23591599',
#  'wwwncbinlmnihgovpubmed22147460',
#  'wwwncbinlmnihgovpubmed18829392',
#  'wwwncbinlmnihgovpubmed24763133',
#  'wwwaccessdatafdagovdrugsatfda_docsnda2014125476orig1s000sumrpdf',
#  'antagonist',
#  '12',
#  '5x',
#  '20',
#  '18',
#  '25',
#  '25',
#  '99',
#  'brodalumab',
#  'hematology',
#  'to',
#  'backs',
#  'thicken',
#  'crosssectional',
#  'pinched',
#  'hardening',
#  'sludge',
#  'clears',
#  'proved',
#  'squashing',
#  '060',
#  '052',
#  '047',
#  '029',
#  '030',
#  '2040',
#  '55',
#  '45',
#  '66',
#  '47',
#  '63',
#  '29',
#  '52',
#  '28',
#  '102',
#  '28',
#  '25',
#  '36',
#  '78',
#  '305',
#  '79',
#  '16',
#  '27',
#  '149',
#  'timolol',
#  '62',
#  '21',
#  '29',
#  '37',
#  '23',
#  '24',
#  '17',
#  '28',
#  '19',
#  '16',
#  '224',
#  '141',
#  '92',
#  '08',
#  '09',
#  '05',
#  '11',
#  '15',
#  '30',
#  'is',
#  'what',
#  'afatinib',
#  'helix',
#  'mutation',
#  'wwwinspirecommdaxys',
#  'blood',
#  'term',
#  '277989',
#  '0015',
#  '0104',
#  '007',
#  '0077',
#  'prnewswire',
#  '65964',
#  '91927',
#  'wwwpmlivecompharma_newspfizer_files_thirdgen_alk_inhibitor_for_lung_cancer_1221723',
#  'wwwcancertherapyadvisorcomlungcancernonsmallcelllungcancercrizotinibalkbrainmetastasesarticle400453',
#  '83',
#  'you',
#  'today',
#  'abby',
#  'is',
#  'what',
#  '008',
#  'could',
#  'but',
#  'limod',
#  'notes',
#  'wwwsciencedirectcomtopicsneurosciencecytokines',
#  'wwwsciencedirectcomtopicsneuroscienceinterleukin',
#  'wwwsciencedirectcomtopicsimmunologyandmicrobiologytumornecrosisfactoralpha',
#  'wwwbioradantibodiescomimmunoglobulinantibodyhtml',
#  'wwwcrohnscolitisfoundationorgresourcesimmunomodulatorshtml',
#  's3euwest1amazonawscomfilescrohnsandcolitisorgukpublicationsazathioprine_ed_4b__feb_2018pdf',
#  'wwwncbinlmnihgovpmcarticlespmc2933759',
#  'wwwncbinlmnihgovpmcarticlespmc4133437',
#  'wwwncbinlmnihgovpubmed2287944',
#  'wwwuptodatecomcontentspharmacologyofcyclosporineandtacrolimus',
#  'wwwcancerorgtreatmenttreatmentsandsideeffectstreatmenttypesimmunotherapymonoclonalantibodieshtml',
#  'wwwuptodatecomcontentstumornecrosisfactoralphainhibitorsinductionofantibodiesautoantibodiesandautoimmunediseases',
#  'wwwremicadecomcrohnsdiseasehowdoesremicadework',
#  'wwwmerckcomproductusapi_circularsrrenflexisrenflexis_pipdf',
#  'labelingpfizercomshowlabelingaspx',
#  'wwwhumiracomcrohnshowhumiraworksforcrohns',
#  'wwwcimziacomlivingwithcd',
#  'wwwsimponicom',
#  'wwwtysabrihcpcomen_ushomeaboutmechanismofactionhtml',
#  'wwwaccessdatafdagovdrugsatfda_docslabel2012125104s0576lblpdf',
#  'wwwentyviohcpcommechanismofaction',
#  'wwwstelarahcpcomcrohnsdiseasemechanismofaction',
#  'shrug',
#  'rich',
#  'ad3',
#  'extracellular',
#  'dependent',
#  'stimulated',
#  'cd14md2',
#  'extraskeletal',
#  'wwwcancergovtypessofttissuesarcomapatientchildsofttissuetreatmentpdq',
#  'reduced',
#  'is',
#  'two',
#  'ipi',
#  'bill',
#  'ascopubsorgdoiabs101200jco20183615_suppl3091',
#  'wwwcanceractivecomarticlemelanomaandskincancersymptomst',
#  '10',
#  'based',
#  'they',
#  'what',
#  'nivolumab',
#  'caused',
#  'nanopore',
#  'tumors',
#  '43',
#  'investoralimerasciencescomindexphpnewsreleasesnewsreleasedetailsalimerasciencesreceivesacceptancefilingobtainapproval',
#  'eyepointpharmacompipeline',
#  '19401948',
#  'cancergraceorglung2015acquiredresistanceinlungcancerpatientforumvideos',
#  '005',
#  '0025',
#  '500',
#  'grin',
#  '2004',
#  'and',
#  'www2govbccaassetsgovhealthhealthdrugcoveragepharmacarenewslettersnews18011pdf',
#  'wwwmerckcastaticpdfrenflexispm_epdf',
#  'wwwcrohnsandcolitiscacrohns_and_colitisdocumentsreportsccfcibdimpactreport2012pdf',
#  'wwwnaturecomarticlesajg201797pdf',
#  'crohnsandcolitiscaaboutcrohnscolitisareyouatrisk',
#  'wwwarthritiscaaboutarthritisarthritistypes',
#  'typesinflammatoryarthritis',
#  'typesrheumatoidarthritis',
#  'rearranged',
#  'associated',
#  '400m',
#  '300m',
#  'originator',
#  '500m',
#  '200300m',
#  'best',
#  'wwwcancergovtypeslungpatientnonsmallcelllungtreatmentpdq',
#  '045',
#  '23',
#  '330',
#  '527',
#  'wwwthediabetescouncilcomultimateguidetothea1ctesteverythingyouneedtoknow',
#  'wwwaaoorgeyehealthtreatmentswhatisopticalcoherencetomography',
#  '414',
#  'wwwdiabeticretinopathyorgukretinopathyprogressionhtm',
#  'wwwdiabeticretinopathyorgukdiabetic_retinopathy_mechhtml',
#  '02',
#  '42',
#  'agerelated',
#  'eye',
#  'clean',
#  '550',
#  '800',
#  '100',
#  '031',
#  '129',
#  '383',
#  '447',
#  '102',
#  'wwwlungcancerfoundationorgpatientsros1trialsandtreatments',
#  'omics',
#  'wwwejogorgarticles03012115',
#  '1017',
#  '493',
#  '90',
#  '45',
#  'flame',
#  'homing',
#  'look',
#  '130',
#  'complications',
#  '175187',
#  'chemsisnlmnihgovchemidpluschemidheavyjsp',
#  '791809',
#  '2519',
#  '24551',
#  '265261',
#  'forumslungevityorgforum31discussionforums',
#  '293000',
#  '690696',
#  'wwwcrohnscolitisfoundationorgassetspdfsunderstandingibdmedsnovpdf',
#  'engineered',
#  'medicare',
#  'll',
#  'not',
#  've',
#  '',
#  '',
#  '',
#  'cancergraceorgblogjimandlisa',
#  'wwwncbinlmnihgovpubmed',
#  'shiftmsmsreporters',
#  'wwwfacebookcomshiftms',
#  'wwwinstagramcomshiftdotms',
#  'twittercomshiftms',
#  '',
#  'insidemystorycom',
#  '',
#  'wwwmstrustorgukazocrelizumab',
#  'active',
#  '_',
#  're',
#  '',
#  'wwwcancergovtypescolorectalpatientcolontreatmentpdq',
#  'wwwncbinlmnihgovpmcarticlespmc',
#  'cancergraceorglungtargetedtherapiesinlungcancerpatientforumpresentationsandhandouts',
#  'wwwmstrustorgukaboutmsmstreatmentsmsdecisionsaid',
#  'wwwgenecommediapressreleasesfdaacceptsgenentechssupplementalbiol',
#  'ive',
#  'dr',
#  'multiplesclerosisresearchblogspotcomclinicspeakswi',
#  'not',
#  'wwwcghjournalorgarticles',
#  '',
#  '',
#  '',
#  'luxury',
#  'sheerling',
#  'cotton',
#  'hot',
#  'alexa',
#  'try',
#  'shower',
#  'cooling',
#  'squatty',
#  '',
#  '',
#  '',
#  '',
#  'in',
#  'anxiety',
#  'without',
#  'yet',
#  'i',
#  'then',
#  'wwwmedpagetodaycommeetingc',
#  'usually',
#  '',
#  '',
#  'weaning',
#  'positive',
#  'wwwnovartiscomnewsmediareleasesnovartisannouncespositive',
#  'wwwmultipleexperiencesorg',
#  'multiplesclerosisresearchblogspotcomsupposetherewa',
#  'wwwmstrustorgukazswallowing',
#  'shiftms',
#  '',
#  'multiplesclerosisresearchblogspotcomcladribinemseffectivediseasehtml',
#  '',
#  '',
#  '',
#  'primary',
#  'activating',
#  '',
#  'cancergraceorgtopictreatmentoptions',
#  'wwwcancergovaboutcancertreatmentcampatientvitamincpdq',
#  'also',
#  'nccihnihgov',
#  'wwwfdagov',
#  'wwwhealiocomhematologyoncol',
#  'cnw',
#  'dale',
#  'wwwcancerresearchukorghealthprofessionalcancerstatisticsstatisticsbycancertypenonhodgkinlymphoma',
#  'does',
#  'early',
#  'but',
#  '',
#  'oh',
#  'the',
#  'specific',
#  'black',
#  'accumulationpresence',
#  'skips',
#  '',
#  '',
#  ...]

# %%
count=0
for tok in toks:
    if (re.match(r'\W',tok)):
        print(tok)
        count +=1

print(count)
# Out:
# //www.crohnscolitisfoundation.org/assets/pdfs/understanding-ibd-meds-nov.pdf
# -engineered
# -medicare
# 'll
# *not
# 've
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ===================================
# ...
# //cancergrace.org/blog/jim-and-lisa
# //www.ncbi.nlm.nih.gov/pubmed/28391420
# //shift.ms/msreporters
# //www.facebook.com/shift.ms/
# //www.instagram.com/shiftdotms/
# //twitter.com/shiftms
# =================================================================
# //insidemystory.com/
# ===============================================================
# //www.mstrust.org.uk/a-z/ocrelizumab
# -active
# ^_^
# 're
# =24
# //www.cancer.gov/types/colorectal/patient/colon-treatment-pdq
# //www.ncbi.nlm.nih.gov/pmc/articles/pmc5401676/
# //cancergrace.org/lung/2017/09/28/targeted-therapies-in-lung-cancer-patient-forum-2017-presentations-and-handouts/
# //www.mstrust.org.uk/about-ms/ms-treatments/ms-decisions-aid
# //www.gene.com/media/press-releases/14773/2019-01-16/fda-accepts-genentechs-supplemental-biol
# +ive
# -dr.
# //multiple-sclerosis-research.blogspot.com/2014/05/clinic-speak-swi
# 'not
# //www.cghjournal.org/article/s1542-3565
# '05
# '15
# '10
# -luxury
# -sheerling
# -cotton
# -hot
# -alexa
# -try
# -shower
# -cooling
# -squatty
# .00001
# .0001
# :1237-42.
# :1235-9.
# 'in
# 'anxiety
# ~without
# ..yet
# ..i
# ..then
# //www.medpagetoday.com/meetingc
# *usually*
# '04
# '17
# *weaning*
# -positive
# //www.novartis.com/news/media-releases/novartis-announces-positive
# //www.multipleexperiences.org
# //multiple-sclerosis-research.blogspot.com/2016/01/suppose-there-wa
# //www.mstrust.org.uk/a-z/swallowing
# //shift.ms/
# 🙏🏾🐻💪🏼
# //multiple-sclerosis-research.blogspot.com/2016/06/cladribine4ms-effective-disease.html
# :172-183.
# :1117-1126.
# :1098-1100.
# ‎primary
# -activating
# ————————-
# //cancergrace.org/topic/treatment-options-2
# //www.cancer.gov/about-cancer/treatment/cam/patient/vitamin-c-pdq
# —also
# //nccih.nih.gov
# //www.fda.gov
# //www.healio.com/hematology-oncol
# /cnw/
# -dale
# //www.cancerresearchuk.org/health-professional/cancer-statistics/statistics-by-cancer-type/non-hodgkin-lymphoma
# *does*
# 'early
# .but
# 👍👍👍
# .oh
# 'the
# -specific
# 'black
# -accumulation-presence
# *skips
# ≥120
# ≥20
# //multiple-sclerosis-research.blogspot.com/2017/03/newsspeak-eagle-
# .6cm
# ..many
# —then
# //multiplesclerosisnewstoday.c
# //cancergrace.org/topic/ned-for-21-months-stop-gilotrif-2-questions-to-dr-west
# //www.mstrust.org.uk/understanding-ms/ms-symptoms-and-treatments/ms-decisions
# //www.ncbi.nlm.nih.gov/pubmed/30677733
# .would
# /genetic
# ­heidelberg
# //www.karger.com/article/fulltext/492322
# –85
# –79
# –95
# –72
# //multiple-sclerosis-research.blogspot.com/2015/10/clinicspeak-headline-ocrelizumab-results.html
# .375
# -4.
# ±5.3
# ≥three
# =0.60
# ≥50
# ≥15
# ≤0.22
# ≤0.03
# //multiple-sclerosis-research.blogspot.com/2015/09/clinicspeak-is-r
# ≥12
# ≥40
# ≥60
# ≥30
# /dose
# ~15
# –blockers
# ≤20
# //www.joslin.org/news/lucentis-proves-effective-against-proliferative-diabetic-retinopathy.html
# //community.mssociety.org.uk/forums/primary-progressive-ms/calling
# 'episode
# :1056-1065.
# //www.fda.gov/newsevents/newsroom/pressannouncements/ucm466413.htm
# .00825
# .001
# –62
# –73
# –82
# –71
# –20
# –16
# –86
# –22
# –10
# –99
# .0008
# .07
# .004
# .0005
# .0002
# -mutant
# :2055217318778610.
# :2055217318777894.
# :sigh
# ..it
# 'unmanaged
# //www.astrazeneca.com/media-centre/press-releases/2018/us-fda-approve
# //www.cancer.gov/research/nci-role/cancer-centers/find
# //www.siteman.wustl.edu
# –45
# –30
# –55
# –90
# –25
# //www.mstrust.org.uk/news/news-about-ms/ocrelizumab-ocrevus-gets-european-licence-relapsing-and-primary-progressive-ms
# //www.flickr.com/photos/argonne/3974983988
# *the
# ———
# //cancergrace.org/lung/tag/zykadia/
# //www.highbeam.com/doc/1g1-470081283.html
# //cancergrace.org/topic/chronic-cough-and-difference-of-opinion
# £50
# //onlinelibrary.ectrims-congress.eu/ectrims/2016/32nd/146337/nicola.de.stefano.cladribine.effect.on.brain.volume.loss.and.its.correlation.html
# //youtu.be/yk7_jpk33i4
# //multiple-sclerosis-research.blogspot.com/2016/06/cladribine4ms-ef
# //www.businesswire.com/news/hom
# -8.6
# -2.6
# //multiple-sclerosis-research.blogspot.com/2015/10/suppose-there-is-therapy-for-ms-that-is.html
# .05
# –24
# //www.medianet.com.au/releases/127433/
# //doi.org/10.1186/s12883-017-0794-5
# +t790m
# .vs
# //mymsaa.org/news-msaa/1380-fda-expedites-review-ocrelizumab
# =0.3
# …..
# ..novartis
# 'everyone
# -ers
# //www.lungcancerfoundation.org/patients/ros1/
# //www.lungcancerfoundation.org/patients/ros1/survey/
# //www.curetoday.com/community/tori-tomalia/2016/07/listen-for-zebras-a-ros1-story
# /per
# -1a
# -1b
# //www.novartis.com
# //twitter.com/novartis
# +41
# //www.frontiersin.org/articles/10.3389/fimmu.2013.00438/full
# 'chesty
# -0.4
# .got
# .just
# –julie
# //www.curetoday.com/articles/immunotherapies-show-promi
# //www.cancer.org/cancer/lungcancer-smallcell/detailedgu
# //www.ncbi.nlm.nih.gov/pubmed/27206905
# =50
# .endpoints
# //smithonstocks.com/northwest-biotherapeutics-dcvax-l-viewed-through-the-eyes-of-dr-linda-liau-lead-investigator-on-the-phase-3-trial-of-dcvax-l-nwbo-0-35-buy/
# //journals.sagepub.com/doi/abs/
# //www.medicaltourisrael.com/wp
# //www.healthline.com/health-news/ms-why-are-ms-drug-prices-so-high-071913
# 'zombie
# :699-710
# :711-21
# :185-90
# *this
# //multiple-sclerosis-research.blogspot.com/2016/01/suppose-there-was-therapy-for-all.html
# +ve
# :8.
# ..sorbelenerecommended
# 'woohoo
# 'failed
# //www.medscape.com/viewarticle/906837
# //www.medscape.com/viewar
# ©2009-2018
# //www.nature.com/ismej/journal/v1/n5/abs/ismej200752a.html
# //www.fascrs.org/patients/disease-condition/crohns-disease-0
# //www.nhs.uk/conditions/crohns-disease/pages/causes.aspx
# //www.cdc.gov/ibd/ibd-epidemiology.htm
# //www.ncbi.nlm.nih.gov/pmc/articles/pmc4087458/
# //gi.org/guideline/management-of-crohns-disease-in-adults/
# //my.clevelandclinic.org/health/articles/crohns-disease
# //www.medicalnewstoday.com/articles/151620.php
# 'reprogramming
# 'eat
# 'super
# .ehealthme
# //www.ehealthme.com/ds/tysabri/pro
# //ccsviinms.blogspot.com
# /skin
# ..also
# ..2ndand3rd
# ..eye
# ..and
# ..each
# .which
# .as
# ..this
# ..since
# ..just
# .gpsaid
# ..one
# .this
# .ive
# .hopefully
# //www.fda.gov/medwatch
# //multiplesclerosisnewstoday.com/2018/08/21/high-ms-activity-seen-patient-after-consecutive-use-immunotherapies-case-report/
# //www.ncbi.nlm.nih.gov/pubmed/30114625
# //cancergrace.org/lung/topic/low-albumin-levels/
# //multiple-sclerosis-research.b
# //www.youtube.com/watch
# 'normal
# 'good
# .has
# .are
# *triples*
# *in
# -pml
# //www.ncbi.nlm.nih.gov/pubmed/23925759
# /quote
# .what
# 'outside
# //fis.fda.gov/hub/stream/aaec8d41-5201-43ab-809f-3063750dfafd
# //www.medicines.org.uk/emc/ima
# ~2~143576b.png
# //www.sciencedirect.com/scienc
# //journals.lww.com/oncology-times/fulltext/2015/04100/warning_about_chemotherapy_afatinib_combination.3.aspx
# :388-397
# //www.ncbi.nlm.nih.gov/pubmed/18574932
# //doi.org/10.1371/journal.pone.0190425
# -hain
# *any
# .jpg
# 'report
# 'knock
# 'hot
# 'that
# //www.ncbi.nlm.nih.gov/pubmed/23868420
# //www.ncbi.nlm.nih.gov/pubmed/23913509
# .not
# ..barts
# .is
# -anticd20s
# -ve
# //www.rituxan.com/hem/hcp
# *scroll
# ~diagnosed
# -vit
# **step
# *permanently*
# -infusions
# -subsequent
# -the
# -if
# -he
# ————————————————————————–
# //www.inspire.com/fighterm/journal/pd1-pd-l1-is-the-superstar-checkpo
# .after
# //neuroimmunology.wordpress.com/2011/11/03/rituximab-vs-ocrelizumab-in-multiple-sclerosis/
# 'whacked
# 'ride
# 'cause
# //multiple-sclerosis-research.blogspot.com/2014/10/offlabel-cladrib
# -every
# ..her
# .357
# £600
# -small-cell
# //www.medpagetoday.com/clinical-context/rheumatoidarthritis/26391
# 'conventional
# //www.ehealthme.com/ds/gilenya/pancreatitis/
# //multiple-sclerosis-research.blogspot.com/
# 'increased
# -my
# -her
# -she
# .the
# *really*
# .50
# 'multum
# ~local
# ​​​​​​
# 'rare
# .06
# //multiplesclerosisnewstoday.com/2018/08/23/switching-from-gilenya-to-rituximab-for-ms-may-be-problem-case-study/
# £1800
# /keytruda
# .02
# -on
# //www.cbsnews.com/video/new-drug-provides-hope-for-those-suffering-with-ms/
# //www.multipleexperiences.org/2017/06/28/ocrelizumab-ocrevus-versus-rituximab-rituxan/
# //cancergrace.org/forums/index.php
# 'fessed
# 'felt
# 'hold
# .works
# //tamingmultiplesclerosis.com/multiplesclerosis-seasonchangesarticle.html
# //multiplesclerosisnewstoday.com/2018/04/16/ocrevus-survey-side-effects-influence-patients-view-of-its-effectiveness/
# //tinyurl.com/genefoocrevus
# 'dangerous
# .and
# 'relapse
# -3922
# //www.healthnewsreview.org/2017/04/fake-breakthrough-fake-news-one-physician-researchers-takeaway-news-coverage-ms-drug-ocrevus/
# //www.ehealthme.com/ds/tysabri/death
# //chefarztfrau.de/
# //www.medpagetoday.com/clinical-co
# //www.ncbi.nlm.nih.gov/pubmed/23100404
# //ms.about.com/od/treatments/a/the
# //www.ncbi.nlm.nih.gov/pubmed/23338729
# //www.ncbi.nlm.nih.gov/pubmed/23252596
# -blocker
# 'no
# //www.mssociety.org.uk/ms-news/2018/04/nice-says-initial-no-ocrelizumab-relapsing-ms
# -wifi
# /www.researchgate.net/publication/318146352_the_risk_of_cancer_in_inflammatory_bowel_disease_does_infliximab_contribute_to_cancer_risk
# —social
# €3500
# .sorry
# …or
# //www.ncbi.nlm.nih.gov/pmc/articles/pmc5869778/
# 'just
# .reread
# -in-law
# ..after
# //www.nytimes.com/2005/03/01/busin
# -but
# //www.iom.edu/~/media/march
# //www.mstrust.org.uk/a-z/exercise
# -mutation–positive
# £300
# //multiple-sclerosis-research.org
# -rebounds/
# //cancergrace.org/lung/tag/immunotherapy-combinations/
# //cancergrace.org/hnscc/2016/08/02/asco-2016-treating-head-and-neck-cancer-using-immunotherapy-as-first-line-treatment-and-in-combinations/
# //cancergrace.org/lung/2015/12/08/gcvl_lu_immunotherapy_combinations_future_treating_lung_cancer/
# -ocular
# /problems
# £70,000
# £35,000,000
# .so
# .considering
# //eur-lex.europa.eu/legal-content/en/auto/
# £84m
# .02.
# //insights.ovid.com/crossref
# ~800
# //cancergrace.org/topic/some-questions-lung-cancer
# 'is
# //www.trademarkia.com/ocrevus-86205182.html
# /pneumonitis
# //cancergrace.org/search-results
# //cancergrace.org/lung/2017/01/12/imprecision-medicine-why-keytruda-pembrolizumab-chemo-for-pd-l1-nsclc-isnt-ready-for-prime-time/
# -while
# =.0025
# //inflammatoryboweldisease.net/treatment/medications/
# 'mary
# -47
# //selfhacked.com/blog/diet-nut
# 'eye
# //www.ema.europa.eu/docs/en_gb/document_library/epar_-_product_information/human/002202/wc500104528.pdf
# //facebook.com/groups/653313891487070
# //clinicaltrials.gov/ct2/show/nct01227954
# //www.rtog.org/news/tabid/72/articletype/articleview/articleid/73/avoidance-of-the-hippocampus-is-shown-to-preserve-memory.aspx
# //www.imsmp.org/content/ocrelizumab-fda-approved-treatment-ms
# …our
# …and
# .now
# ..not
# //app.jamanetwork.com/
# //www.nice.org.uk/guidance/gid-ta10153/documents/appraisal-consult
# ±sd
# ±6.3
# ±0.1
# ±0.6
# ±0.2
# ±9.9
# ±8.6
# -80
# //www.cnn.com/2018/03/02/health/ms-drug-daclizumab-pulled-bn/index.html
# //multiple-sclerosis-research.blogspot.com/2017/12/pml-warning-on-cladribine-by-mhra-has.html
# //doi.org/
# //cancergrace.org/cancer-101/2013/01/06/clin-trials-ramalingam-pt-1/
# //cancergrace.org/cancer-101/2013/01/18/how-are-clin-trials-developed/
# //cancergrace.org/cancer-101/2013/01/27/ramalingam-clin-trials-pt-3/
# //www.aao.org/eye-health/diseases/avastin-eylea-lucentis-difference
# 'treatment
# //fis.fda.gov/sense/app/777e9f4d-0cf8-448e-8068-f564c31baa25/sheet/45beeb74-30ab-46be-8267-5756582633b4/state/analysis
# //www.ocrevus.com/patient/safety.html
# //www.pharma.us.novartis.com/news/media-releases/novartis-announces-fda-filing-acceptance-siponimod-baf312-first-and-only-oral
# //www.gofundme.com/6c89ruo
# £100,000
# £60,000
# ☺…there
# '01
# '02
# //www.mymsaa.org/about-ms/sources/
# //www.fema.gov/regional-operations/state-offices-and-agencies-emergency-management
# *article
# //www.umcor.org/umcor/resources/news-stories/2012/october/how-to-help-do-this-not-that
# //www.ic3.gov/media/2011/110311.aspx
# //www.state.nj.us/njoem/
# //disastercenter.com/newjersy/newjersy.htm
# //www.dhses.ny.gov/oem/
# //disastercenter.com/newyork/newyork.htm
# //www.nyredcross.org/
# //www.foodbanknyc.org/
# /urination
# //multiple-sclerosis-research.blogspot.com/2016/04/researchspeak-rituxumab-vs-fingolimod.html
# .multiple
# //www.thestreet.com/story/14006548/1/celgene-multiple-sclerosis-pill-succeeds-in-first-late-stage-clinical-trial.html
# //multiple-sclerosis-research.blogspot.com/2017/06/hsct-in-progressive-ms.html
# .014
# .003
# .05-.001
# .622
# .015
# .09
# .12
# //msddjournal.biomedcentral.co
# :2122-2133.
# :20-29.
# :585-602.
# :141-147.
# :591-600.
# :572-573.
# :4-16.
# :204-216
# //www.ema.europa.eu/ema/index.jsp
# ~10lbs
# .5mg
# ≥2.54
# //www.ncbi.nlm.nih.gov/pubmed/12528101
# //www.ncbi.nlm.nih.gov/pubmed/7779114
# //www.ncbi.nlm.nih.gov/pubmed/8507213
# //www.ncbi.nlm.nih.gov/pubmed/9751088
# //www.ncbi.nlm.nih.gov/pubmed/8633113
# //www.ncbi.nlm.nih.gov/pubmed/12379628
# //www.pubmedcentral.nih.gov/picrender.fcgi
# //www.ncbi.nlm.nih.gov/pubmed/15146409
# //www.ncbi.nlm.nih.gov/pubmed/16200601
# //www.ncbi.nlm.nih.gov/pubmed/16802350
# //www.fda.gov/drugs/drugsafety/postmarketdrugsafetyinformationforpatientsandproviders/drugsafetyinformationforheathcareprofessionals/ucm174474.htm
# //www.fda.gov/drugs/drugsafety/postmarketdrugsafetyinformationforpatientsandproviders/ucm124185.htm
# //www.ncbi.nlm.nih.gov/pubmed/18716298
# //www.ncbi.nlm.nih.gov/pubmed/9321530
# //www.fda.gov/downloads/drugs/drugsafety/postmarketdrugsafetyinformationforpatientsandproviders/ucm224377.pdf
# //www.fda.gov/drugs/drugsafety/ucm270849.htm
# //www.fda.gov/drugs/drugsafety/ucm250913.htm
# //www.ncbi.nlm.nih.gov/pubmed/21083543
# //www.ncbi.nlm.nih.gov/pubmed/21209123
# //www.ncbi.nlm.nih.gov/pubmed/22062358
# //www.ncbi.nlm.nih.gov/pubmed/23665965
# .066
# .011
# -mutated
# +/-
# //cancergrace.org/lung/tag/oligoprogression/
# ++â
# 'wet
# -neutralizing
# //www.diabeticretinopathy.org.uk/lucentispatientsdr.htm
# 'out
# ~jennifer
# //www.ucsf.edu/news/2017/03/406296/new-multiple-sclerosis-drug-ocrelizumab-could-halt-disease
# //www.davidscampathstory.org/index.html
# //www.justgiving.com/fundraising/mark-seacombe1
# //tedxchelmsford.com/works/ellen-marshall/
# //www.express.co.uk/news/uk/610907/multiple-sclerosis-drug-ocrelizumab-treatment-britain-gavin-giovannoni-nick-rijke
# /0.005
# //www.businesswire.com/news/home/20190117005165/en/
# //www.businesswire.com/news/home/20190117005165/en
# -in
# -when
# -ointment
# -steroid
# -following
# -patients
# 'steroid
# .methodsfifteen
# //aircharitynetwork.org/request-a-flight/
# //lifelinepilots.org/
# //www.corpangelnetwork.org/
# //mercymedical.org/
# //www.lazarex.org/
# //embenkickscancer.wordpress.com/
# //wp.vcu.edu/hemeoncfellowship/wp-content/uploads/sites/3982/2017/08/keynote-021-carbo-pemetrexed-pembrolizumab-in-advanced-non-squamous-nsclc-2016-lancet.pdf
# -189
# -227
# -line
# =0.29
# =0.11
# =0.22
# =0.2
# //ow.ly/kcbt306wdbn
# -glucose
# -positron
# =0.01
# .0003
# .0020
# .0018
# //www.inspire.com/groups/american-lung-association-lung-cancer-survivors/discussion/duravalumab-imfinzi-patients-support-group/
# //www.cancer.ca/en/cancer-information/cancer-type/lung/treatment/chemotherapy/
# :228-33
# *outside*
# –70.9
# –50.8
# .092
# //clinicaltrials.gov/ct2/show/nct02349633
# .002
# .537
# .6.
# —antibodies
# -approved
# -γ-induced
# .023
# …thayr-uh-pee
# ..an-tih-jen
# …lih-nee-er
# …glee-oh-muh
# //www.cancer.gov/types/soft-tissue-sarcoma/patient/rhabdomyosarcoma-treatment-pdq
# ~1/2
# ~50
# ~10
# ~80
# :459-465.
# :976-983.
# //nccn.org
# //clinicaltrials.gov/ct2/show/nct02659059
# //clincancerres.aacrjournals.org/content/20/9/2424.full
# -scohn
# //link.springer.com/10.1007/s12325-018-0848-0
# //newsroom.regeneron.com
# //twitter.com/regeneron
# -dk
# -driven
# -y393
# =.001
# //adventuresinlivingterminallyopti
# …has
# born
# patient
# -health
# health
# //www.cancer.gov/news-events/cancer-currents-blog/2017/genomic-profiling-tests-cancer
# //www.cancer.gov/news-events/cancer-currents-blog/2019/early-stage-lung-cancer-biomarker
# –nccn
# //www.kaltura.com/index.php/extwidget/preview/partner_id/2207941/uiconf_id/40195191/entry_id/1_7m16l2ov/embed/iframe
# ..lol
# 'limited
# //ros1cancer.com
# //www.clinicaltrials.gov/ct2/show/nct02034981
# ~4000
# ~2400
# ~2900
# ~4500
# ~700
# ~1200
# *much
# //www.mskcc.org/experience/become-patient/appointment
# //multiple-sclerosis-research.blogspot.com/2017/08/teamg-helps-develop-licenced-drug.html
# //www.medicines.org.uk/emc/product/1438/smpc
# ******************************
# //www.mstrust.org.uk/a-z/mavenclad-cladribine
# :1956-1957
# :459-469
# :288-94
# :2230-2237
# -32.5
# -26.1
# -7.5
# .01
# -mutation
# 'socialized
# //journals.lww.com/co-gastroenterology/fulltext/2018/11000/checkpoint_inhi
# .for
# —use
# //onlinelibrary.wiley.com/doi/pdf/10.1111/apt.13847
# -40
# -30
# //www.ncbi.nlm.nih.gov/pmc/articles/pmc4872064/
# -hopefully
# //clinicaltrials.gov/show/nct02888743
# ≤8.0
# .0095
# =.007
# =.02
# .when
# -paclitaxel
# .056
# //www.technologynetworks.com/cancer-research/news/unstable-chromosomes-increase-risk-of-cancer-returning-288099
# =.005
# //cancergrace.org/topic/medi4736/page/3/
# /url
# ….we
# ….immunotherapy
# /carboplatin
# .25
# -moonface
# -weight
# -swelling
# -bad
# -brain
# -dizziness
# -increased
# -irritability
# *******************no
# //www.ncbi.nlm.nih.gov/pubmed/30644981
# //amzn.to/2hgi0rt
# //www.ema.europa.eu/medicines/human/epar/avastin
# //www.ema.europa.eu/medicines/human/epar/keytruda
# -you
# ***will
# ***
# -injection
# -this
# -mtx
# //www.ncbi.nlm.nih.gov/pubmed/30536638
# ≥24
# ≥65
# //www.ncbi.nlm.nih.gov/pubmed/24842416
# //www.ncbi.nlm.nih.gov/pubmed/24799843
# //www.ncbi.nlm.nih.gov/pubmed/15958805
# //www.ncbi.nlm.nih.gov/pubmed/23964932
# //www.ncbi.nlm.nih.gov/pubmed/24899819
# //www.ncbi.nlm.nih.gov/pubmed/23723689
# //www.ncbi.nlm.nih.gov/pubmed/23046232
# //www.ncbi.nlm.nih.gov/pubmed/25211302
# //www.ncbi.nlm.nih.gov/pubmed/21180594
# //www.ncbi.nlm.nih.gov/pubmed/23964933
# :1-24
# //www.ncbi.nlm.nih.gov/pubmed/24859203
# //www.ncbi.nlm.nih.gov/pubmed/25309060
# //www.ncbi.nlm.nih.gov/pubmed/19509315
# //www.ncbi.nlm.nih.gov/pubmed/23591599
# //www.ncbi.nlm.nih.gov/pubmed/22147460
# //www.ncbi.nlm.nih.gov/pubmed/18829392
# //www.ncbi.nlm.nih.gov/pubmed/24763133
# //www.accessdata.fda.gov/drugsatfda_docs/nda/2014/125476orig1s000sumr.pdf
# -antagonist
# ≤1.2
# ≥5x
# ~20
# ≤18
# ≤25
# ~25
# ≥99
# —brodalumab
# -hematology
# -to
# 'backs
# 'thicken
# 'cross-sectional
# 'pinched
# 'hardening
# 'sludge
# 'clears
# 'proved
# 'squashing
# ±0.60
# ±0.52
# ±0.47
# ±0.29
# ≤0.30
# ≥20/40
# +5.5
# +4.5
# +6.6
# +4.7
# +6.3
# +2.9
# +5.2
# +28
# +10.2
# +2.8
# -2.5
# +36
# +7.8
# +30.5
# +7.9
# +1.6
# -2.7
# -1.49
# /timolol
# ±6.2
# ≤21
# ±2.9
# ±3.7
# ±2.3
# ±2.4
# ±1.7
# ±2.8
# ±1.9
# ±1.6
# ±22.4
# ±14.1
# ±9.2
# ±0.8
# ±0.9
# ±0.5
# ±1.1
# ±15
# ±30
# ***is
# ***what
# -afatinib
# -helix
# –mutation
# //www.inspire.com/m/daxys/
# 'blood
# ‐term
# :2779-89
# .0015
# .0104
# .007
# .0077
# /prnewswire/
# :659-64
# :919-27
# //www.pmlive.com/pharma_news/pfizer_files_third-gen_alk_inhibitor_for_lung_cancer_1221723
# //www.cancertherapyadvisor.com/lung-cancer/non-small-cell-lung-cancer-crizotinib-alk-brain-metastases/article/400453/
# –83
# ..you
# .today
# —abby
# *is
# *what
# .008
# ….could
# ….but
# *****limod
# *notes
# //www.sciencedirect.com/topics/neuroscience/cytokines
# //www.sciencedirect.com/topics/neuroscience/interleukin
# //www.sciencedirect.com/topics/immunology-and-microbiology/tumor-necrosis-factor-alpha
# //www.bio-rad-antibodies.com/immunoglobulin-antibody.html
# //www.crohnscolitisfoundation.org/resources/immunomodulators.html
# //s3-eu-west-1.amazonaws.com/files.crohnsandcolitis.org.uk/publications/azathioprine_ed_4b_-_feb_2018.pdf
# //www.ncbi.nlm.nih.gov/pmc/articles/pmc2933759/
# //www.ncbi.nlm.nih.gov/pmc/articles/pmc4133437/
# //www.ncbi.nlm.nih.gov/pubmed/2287944
# //www.uptodate.com/contents/pharmacology-of-cyclosporine-and-tacrolimus
# //www.cancer.org/treatment/treatments-and-side-effects/treatment-types/immunotherapy/monoclonal-antibodies.html
# //www.uptodate.com/contents/tumor-necrosis-factor-alpha-inhibitors-induction-of-antibodies-autoantibodies-and-autoimmune-diseases
# //www.remicade.com/crohns-disease/how-does-remicade-work
# //www.merck.com/product/usa/pi_circulars/r/renflexis/renflexis_pi.pdf
# //labeling.pfizer.com/showlabeling.aspx
# //www.humira.com/crohns/how-humira-works-for-crohns
# //www.cimzia.com/living-with-cd
# //www.simponi.com/
# //www.tysabrihcp.com/en_us/home/about/mechanism-of-action.html
# //www.accessdata.fda.gov/drugsatfda_docs/label/2012/125104s0576lbl.pdf
# //www.entyviohcp.com/mechanism-of-action
# //www.stelarahcp.com/crohns-disease/mechanism-of-action
# *shrug*
# -rich
# /ad3
# /extracellular
# -dependent
# -stimulated
# /cd14/md2
# /extraskeletal
# //www.cancer.gov/types/soft-tissue-sarcoma/patient/child-soft-tissue-treatment-pdq
# —reduced
# —is
# —two
# /ipi
# -bill
# //ascopubs.org/doi/abs/10.1200/jco.2018.36.15_suppl.3091
# //www.canceractive.com/article/melanoma-and-skin-cancer-symptoms-t
# ≥10
# —based
# —they
# ►what
# ​nivolumab
# -caused
# nanopore
# /tumors
# -43
# //investor.alimerasciences.com/index.php/news-releases/news-release-details/alimera-sciences-receives-acceptance-filing-obtain-approval
# //eyepointpharma.com/pipeline/
# :1940-1948
# //cancergrace.org/lung/2015-acquired-resistance-in-lung-cancer-patient-forum-videos/
# .005
# .0025
# ≥500
# :grin
# –2004
# -and
# //www2.gov.bc.ca/assets/gov/health/health-drug-coverage/pharmacare/newsletters/news18-011.pdf
# //www.merck.ca/static/pdf/renflexis-pm_e.pdf
# //www.crohnsandcolitis.ca/crohns_and_colitis/documents/reports/ccfc-ibd-impact-report-2012.pdf
# //www.nature.com/articles/ajg201797.pdf
# //crohnsandcolitis.ca/about-crohn-s-colitis/are-you-at-risk
# //www.arthritis.ca/about-arthritis/arthritis-types-
# /types/inflammatory-arthritis
# /types/rheumatoid-arthritis
# -rearranged
# -associated
# £400m
# £300m
# 'originator
# £500m
# £200-300m
# 'best
# //www.cancer.gov/types/lung/patient/non-small-cell-lung-treatment-pdq
# -0.45
# -2.3
# -330
# -527
# //www.thediabetescouncil.com/ultimate-guide-to-the-a1c-test-everything-you-need-to-know/
# //www.aao.org/eye-health/treatments/what-is-optical-coherence-tomography
# :4-14.
# //www.diabeticretinopathy.org.uk/retinopathyprogression.htm
# //www.diabeticretinopathy.org.uk/diabetic_retinopathy_mech.html
# +0.2
# +4.2
# 'age-related
# ©eye
# 'clean
# £550
# £800
# £100
# ,031
# £129
# £383
# £447
# £102
# //www.lungcancerfoundation.org/patients/ros1/trials-and-treatments/
# -omics
# //www.ejog.org/article/s0301-2115
# :1017.
# :493.
# ≥90
# +45
# 'flame
# 'homing
# 'look
# ≤130
# 'complications
# :175–187
# //chem.sis.nlm.nih.gov/chemidplus/chemidheavy.jsp
# :791-809.
# :251-9.
# :245-51.
# :2652-61.
# //forums.lungevity.org/forum/31-discussion-forums/
# £293,000
# :690-696.
# 905

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ravishankarbhati/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.pos_tag("Ravi is awesome. accumulation-presence He is going to Jail. ≤0.03 .375 // //multiple-sclerosis-research.blogspot.com/2015/09/clinicspeak-is-r".split())
# Out:
# [('Ravi', 'NNP'),
#  ('is', 'VBZ'),
#  ('awesome.', 'JJ'),
#  ('accumulation-presence', 'NN'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('Jail.', 'NNP'),
#  ('≤0.03', 'NNP'),
#  ('.375', 'NNP'),
#  ('//', 'NNP'),
#  ('//multiple-sclerosis-research.blogspot.com/2015/09/clinicspeak-is-r', 'NN')]
